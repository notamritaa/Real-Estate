# %% [markdown]
# This is a starter notebook for the project, you'll have to import the libraries you'll need, you can find a list of the ones available in this workspace in the requirements.txt file in this workspace.

# %% [markdown]
# # Import librairies
# - please note chromadb was pinned to 0.4.15 to be compatible with langchain OpenAIEmbeddings parameters (incompatibility issue https://github.com/langchain-ai/langchain/discussions/14411)

# %%
import os, json
from IPython.display import Markdown, display
import pandas as pd
import numpy as np
from pprint import pprint

from dotenv import load_dotenv, find_dotenv
# load up the .env file with secrets
_ = load_dotenv(find_dotenv())

from pydantic import BaseModel, Field, NonNegativeInt
from typing import List, Optional, Type

from langchain.llms import OpenAI
from langchain.chat_models import ChatOpenAI
from langchain.vectorstores import Chroma
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.output_parsers import PydanticOutputParser
from langchain.document_loaders import CSVLoader  #JSONLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter, CharacterTextSplitter
from langchain.output_parsers import ResponseSchema
from langchain.output_parsers import StructuredOutputParser
from langchain.prompts import (ChatPromptTemplate,
                               PromptTemplate,
                               SystemMessagePromptTemplate,
                               AIMessagePromptTemplate,
                               HumanMessagePromptTemplate,
                               )
from langchain.schema import AIMessage, HumanMessage, SystemMessage, FunctionMessage
from langchain.utils.openai_functions import convert_pydantic_to_openai_function
from langchain.agents.output_parsers import OpenAIFunctionsAgentOutputParser
from langchain.tools import BaseTool, format_tool_to_openai_function
from langchain import LLMChain

import openai

# %% [markdown]
# # Key modules and parameters

# %%
# colors definition
ENDC = '\33[0m'
RED = '\33[31m'
GREEN = '\33[32m'
YELLOW = '\33[33m'
VIOLET = '\33[35m'
CYAN = '\33[36m'

# %%
# Instantiate an OpenAI API client using langchain
instruct_llm = OpenAI(model="gpt-3.5-turbo-instruct", 
             openai_api_key=os.getenv('OPENAI_API_KEY'),
             temperature=0, 
             max_tokens=3500)

chat_llm = ChatOpenAI(model="gpt-3.5-turbo", 
             openai_api_key=os.getenv('OPENAI_API_KEY'),
             temperature=0, 
             max_tokens=3500)

import chromadb
persist_directory = './data/vectordb'
client = chromadb.PersistentClient(path=persist_directory)

embeddings_model = OpenAIEmbeddings(openai_api_key=os.getenv('OPENAI_API_KEY'))

# %% [markdown]
# # STEP 1 - GENERATE SYNTHETIC REAL ESTATE LISTINGS
# - we want to generate synthetic listings to use as our test database
# - we will use chatGPT to generate these listings

# %%
# Prepare property description examples for two-shot learning
listing_examples = ['''Headline: A 3-bedroom, 2-bathroom home in Green Oaks
Neighborhood: Green Oaks
Price: €1,200,000
Bedrooms: 3
Bathrooms: 2
House Size (sqm): 110

Description: Welcome to this eco-friendly oasis nestled in the heart of Green Oaks. This charming 3-bedroom, 2-bathroom home boasts energy-efficient features such as solar panels and a well-insulated structure. Natural light floods the living spaces, highlighting the beautiful hardwood floors and eco-conscious finishes. The open-concept kitchen and dining area lead to a spacious backyard with a vegetable garden, perfect for the eco-conscious family. Embrace sustainable living without compromising on style in this Green Oaks gem.

Neighborhood Description: Green Oaks is a close-knit, environmentally-conscious community with access to organic grocery stores, community gardens, and bike paths. Take a stroll through the nearby Green Oaks Park or grab a cup of coffee at the cozy Green Bean Cafe. With easy access to public transportation and bike lanes, commuting is a breeze.''',
'''Headline: Charming Oasis in Neuilly
Neighborhood: Neuilly
Price: €2,000,000
Bedrooms: 5
Bathrooms: 2
House Size (sqm): 180

Description: Discover this enchanting family home nestled in the heart of Neuilly. With its timeless elegance and modern amenities, it’s the perfect sanctuary for your family.

Neighborhood Description: Neuilly offers a serene lifestyle, top-rated schools, and picturesque parks. Enjoy the tranquility while being conveniently close to amenities.
''']
# convert examples to one string
listing_samples = '\n---------------------------------\n'.join(listing_examples)

# Pydantic models for the listings data
class listings_description_model(BaseModel):
    listings_headline: str = Field(description='property headline')
    listings_neighborhood: str = Field(description='property neighborhood where the home is located')
    listings_price: NonNegativeInt = Field(description='property price')
    listings_bedrooms: NonNegativeInt = Field(description='property number of bedrooms')
    listings_bathrooms: NonNegativeInt = Field(description='property number of bathrooms')
    listings_house_size: NonNegativeInt = Field(description='property house size')
    listings_description: str = Field(description='property description following the guidelines')
    listings_neighborhood_description: str = Field(description='property neighborhood description')

class listings_descriptions(listings_description_model):
    list_of_listings: List[listings_description_model] = Field(description='list of property descriptions following the guidelines')

parser = PydanticOutputParser(pydantic_object=listings_descriptions)
print(parser.get_format_instructions())


# Prompt to generate synthetic listing data using examples and pydantic model
template_genlistings = '''You are a real estate agent tasked with creating property listings for a variety of homes in different neighborhoods. Your goal is to craft compelling descriptions that entice potential buyers. Follow these guidelines for each listing:
1. Headline: Begin with an attention-grabbing opening sentence that captures the viewer's interest in the home.
2. In Bullet points:
    - Neighborhood: The name of the neighborhood where the home is located.
    - **Price**: Mention the price.
    - **Bedrooms**: Specify the number of bedrooms (e.g., 5).
    - **Bathrooms**: Specify the number of bathrooms (e.g., 2).
    - **House Size in sqm**: Provide the exact square footage (e.g., 150).
3. Property Description: Include a brief description of the home and its features.
4. Neighborhood description: Briefly describe the neighborhood.

========== EXEMPLES ==========
{listing_samples}
========== END OF EXAMPLES ==========

Remember to be succinct, informative, and persuasive.
**Only use the requested format.**
{format_instructions}
'''

prompt = PromptTemplate.from_template(template_genlistings,
                                      partial_variables={'format_instructions':parser.get_format_instructions})

system_prompt = prompt.format(listing_samples=listing_samples)
# Out:
# The output should be formatted as a JSON instance that conforms to the JSON schema below.
#
# As an example, for the schema {"properties": {"foo": {"title": "Foo", "description": "a list of strings", "type": "array", "items": {"type": "string"}}}, "required": ["foo"]}
# the object {"foo": ["bar", "baz"]} is a well-formatted instance of the schema. The object {"properties": {"foo": ["bar", "baz"]}} is not well-formatted.
#
# Here is the output schema:
# ```
# {"$defs": {"listings_description_model": {"properties": {"listings_headline": {"description": "property headline", "title": "Listings Headline", "type": "string"}, "listings_neighborhood": {"description": "property neighborhood where the home is located", "title": "Listings Neighborhood", "type": "string"}, "listings_price": {"description": "property price", "minimum": 0, "title": "Listings Price", "type": "integer"}, "listings_bedrooms": {"description": "property number of bedrooms", "minimum": 0, "title": "Listings Bedrooms", "type": "integer"}, "listings_bathrooms": {"description": "property number of bathrooms", "minimum": 0, "title": "Listings Bathrooms", "type": "integer"}, "listings_house_size": {"description": "property house size", "minimum": 0, "title": "Listings House Size", "type": "integer"}, "listings_description": {"description": "property description following the guidelines", "title": "Listings Description", "type": "string"}, "listings_neighborhood_description": {"description": "property neighborhood description", "title": "Listings Neighborhood Description", "type": "string"}}, "required": ["listings_headline", "listings_neighborhood", "listings_price", "listings_bedrooms", "listings_bathrooms", "listings_house_size", "listings_description", "listings_neighborhood_description"], "title": "listings_description_model", "type": "object"}}, "properties": {"listings_headline": {"description": "property headline", "title": "Listings Headline", "type": "string"}, "listings_neighborhood": {"description": "property neighborhood where the home is located", "title": "Listings Neighborhood", "type": "string"}, "listings_price": {"description": "property price", "minimum": 0, "title": "Listings Price", "type": "integer"}, "listings_bedrooms": {"description": "property number of bedrooms", "minimum": 0, "title": "Listings Bedrooms", "type": "integer"}, "listings_bathrooms": {"description": "property number of bathrooms", "minimum": 0, "title": "Listings Bathrooms", "type": "integer"}, "listings_house_size": {"description": "property house size", "minimum": 0, "title": "Listings House Size", "type": "integer"}, "listings_description": {"description": "property description following the guidelines", "title": "Listings Description", "type": "string"}, "listings_neighborhood_description": {"description": "property neighborhood description", "title": "Listings Neighborhood Description", "type": "string"}, "list_of_listings": {"description": "list of property descriptions following the guidelines", "items": {"$ref": "#/$defs/listings_description_model"}, "title": "List Of Listings", "type": "array"}}, "required": ["listings_headline", "listings_neighborhood", "listings_price", "listings_bedrooms", "listings_bathrooms", "listings_house_size", "listings_description", "listings_neighborhood_description", "list_of_listings"]}
# ```

# %%
# Call GPT-3 to generate 15 listings following above guidelines.
response = openai.ChatCompletion.create(
          model="gpt-3.5-turbo",
          messages=[
          {
            "role": "system",
            "content": system_prompt
          },
          {
            "role": "user",
            "content": "Generate 15 listings following these guidelines."
          }
          ],
        temperature=0,
        max_tokens=4000,
        )

# %% [markdown]
# #### RUBRIC #1 Generating Real Estate Listings with an LLM

# %% [markdown]
# - post processing to extract the listings

# %%
print(response.choices[0].message['content'][:-2])
# Out:
# {
#     "listings_headline": "Modern Luxury in Central Park",
#     "listings_neighborhood": "Central Park",
#     "listings_price": 3500000,
#     "listings_bedrooms": 4,
#     "listings_bathrooms": 3,
#     "listings_house_size": 280,
#     "listings_description": "Indulge in the epitome of modern luxury with this stunning 4-bedroom, 3-bathroom home in Central Park. Boasting high-end finishes, a gourmet kitchen, and panoramic views of the city skyline, this property offers a sophisticated urban lifestyle.",
#     "listings_neighborhood_description": "Central Park is a vibrant neighborhood known for its upscale dining, shopping, and cultural attractions. Enjoy easy access to the park for leisurely strolls and outdoor activities."
# },
# {
#     "listings_headline": "Seaside Retreat in Ocean View",
#     "listings_neighborhood": "Ocean View",
#     "listings_price": 1800000,
#     "listings_bedrooms": 3,
#     "listings_bathrooms": 2,
#     "listings_house_size": 200,
#     "listings_description": "Escape to this charming seaside retreat in Ocean View. With 3 bedrooms, 2 bathrooms, and a spacious deck overlooking the ocean, this home offers a perfect blend of coastal living and modern comfort.",
#     "listings_neighborhood_description": "Ocean View is a picturesque coastal community with sandy beaches, seafood restaurants, and a laid-back atmosphere. Experience the tranquility of seaside living in this charming neighborhood."
# },
# {
#     "listings_headline": "Historic Elegance in Heritage District",
#     "listings_neighborhood": "Heritage District",
#     "listings_price": 1200000,
#     "listings_bedrooms": 5,
#     "listings_bathrooms": 4,
#     "listings_house_size": 320,
#     "listings_description": "Step back in time with this historic 5-bedroom, 4-bathroom home in the Heritage District. Featuring elegant architecture, a grand staircase, and a beautifully landscaped garden, this property exudes timeless charm.",
#     "listings_neighborhood_description": "The Heritage District is a historic neighborhood filled with tree-lined streets, heritage homes, and boutique shops. Immerse yourself in the rich history and architectural beauty of this unique district."
# },
# {
#     "listings_headline": "Contemporary Living in Skyline Heights",
#     "listings_neighborhood": "Skyline Heights",
#     "listings_price": 2800000,
#     "listings_bedrooms": 6,
#     "listings_bathrooms": 5,
#     "listings_house_size": 400,
#     "listings_description": "Experience contemporary living at its finest in this 6-bedroom, 5-bathroom home in Skyline Heights. With sleek design, high ceilings, and a rooftop terrace with city views, this property is perfect for modern urban dwellers.",
#     "listings_neighborhood_description": "Skyline Heights offers a vibrant urban lifestyle with trendy cafes, art galleries, and easy access to public transportation. Enjoy the bustling energy of the city from the comfort of your stylish home."
# },
# {
#     "listings_headline": "Tranquil Haven in Willow Creek",
#     "listings_neighborhood": "Willow Creek",
#     "listings_price": 1500000,
#     "listings_bedrooms": 4,
#     "listings_bathrooms": 3,
#     "listings_house_size": 250,
#     "listings_description": "Find peace and serenity in this tranquil 4-bedroom, 3-bathroom home in Willow Creek. Surrounded by lush greenery, with a private backyard and a cozy fireplace, this property offers a perfect retreat from the hustle and bustle of city life.",
#     "listings_neighborhood_description": "Willow Creek is a quiet residential neighborhood known for its tree-lined streets, parks, and family-friendly atmosphere. Enjoy a sense of community and nature in this peaceful enclave."
# },
# {
#     "listings_headline": "Urban Chic in Downtown District",
#     "listings_neighborhood": "Downtown District",
#     "listings_price": 2000000,
#     "listings_bedrooms": 3,
#     "listings_bathrooms": 2,
#     "listings_house_size": 180,
#     "listings_description": "Embrace urban chic living in this stylish 3-bedroom, 2-bathroom home in the heart of the Downtown District. With modern design, high-end appliances, and a rooftop patio for entertaining, this property is perfect for those who love city living.",
#     "listings_neighborhood_description": "The Downtown District is a bustling urban center with a vibrant nightlife, trendy restaurants, and cultural attractions. Experience the excitement of city life right outside your doorstep."
# },
# {
#     "listings_headline": "Rustic Charm in Maple Grove",
#     "listings_neighborhood": "Maple Grove",
#     "listings_price": 1300000,
#     "listings_bedrooms": 4,
#     "listings_bathrooms": 3,
#     "listings_house_size": 220,
#     "listings_description": "Discover the rustic charm of this 4-bedroom, 3-bathroom home in Maple Grove. With exposed wooden beams, a cozy fireplace, and a spacious backyard with a fire pit, this property offers a warm and inviting atmosphere.",
#     "listings_neighborhood_description": "Maple Grove is a quaint neighborhood with tree-lined streets, local cafes, and boutique shops. Enjoy a sense of community and small-town charm in this cozy enclave."
# },
# {
#     "listings_headline": "Luxurious Retreat in Hillside Manor",
#     "listings_neighborhood": "Hillside Manor",
#     "listings_price": 3000000,
#     "listings_bedrooms": 5,
#     "listings_bathrooms": 4,
#     "listings_house_size": 350,
#     "listings_description": "Escape to a luxurious retreat in the prestigious Hillside Manor. This 5-bedroom, 4-bathroom home features a gourmet kitchen, a home theater, and a landscaped garden with a pool, offering the ultimate in upscale living.",
#     "listings_neighborhood_description": "Hillside Manor is an exclusive neighborhood known for its luxury estates, private golf courses, and scenic views. Enjoy privacy and sophistication in this upscale enclave."
# },
# {
#     "listings_headline": "Coastal Living in Seaview Heights",
#     "listings_neighborhood": "Seaview Heights",
#     "listings_price": 2200000,
#     "listings_bedrooms": 3,
#     "listings_bathrooms": 2,
#     "listings_house_size": 190,
#     "listings_description": "Experience the beauty of coastal living in this 3-bedroom, 2-bathroom home in Seaview Heights. With ocean views, a sun-drenched deck, and beach access just steps away, this property offers a perfect seaside retreat.",
#     "listings_neighborhood_description": "Seaview Heights is a coastal community with sandy beaches, seaside cafes, and water sports activities. Enjoy the laid-back lifestyle and stunning ocean views in this charming neighborhood."
# },
# {
#     "listings_headline": "Elegant Oasis in Rosewood Estates",
#     "listings_neighborhood": "Rosewood Estates",
#     "listings_price": 2600000,
#     "listings_bedrooms": 4,
#     "listings_bathrooms": 3,
#     "listings_house_size": 240,
#     "listings_description": "Discover an elegant oasis in the prestigious Rosewood Estates. This 4-bedroom, 3-bathroom home features a grand foyer, a gourmet kitchen, and a landscaped backyard with a fountain, offering a perfect blend of luxury and sophistication.",
#     "listings_neighborhood_description": "Rosewood Estates is an upscale neighborhood known for its luxury homes, private estates, and exclusive country clubs. Experience the epitome of luxury living in this prestigious enclave."
# },
# {
#     "listings_headline": "Serenity in Pinecrest Meadows",
#     "listings_neighborhood": "Pinecrest Meadows",
#     "listings_price": 1700000,
#     "listings_bedrooms": 5,
#     "listings_bathrooms": 4,
#     "listings_house_size": 260,
#     "listings_description": "Find serenity in this 5-bedroom, 4-bathroom home in Pinecrest Meadows. Surrounded by towering pine trees, with a wrap-around porch and a cozy fireplace, this property offers a peaceful retreat in a natural setting.",
#     "listings_neighborhood_description": "Pinecrest Meadows is a nature lover's paradise with hiking trails, wildlife, and scenic views. Enjoy the tranquility and beauty of the outdoors in this idyllic neighborhood."
# },
# {
#     "listings_headline": "Modern Elegance in Silver Lake",
#     "listings_neighborhood": "Silver Lake",
#     "listings_price": 1900000,
#     "listings_bedrooms": 3,
#     "listings_bathrooms": 2,
#     "listings_house_size": 210,
#     "listings_description": "Experience modern elegance in this 3-bedroom, 2-bathroom home in Silver Lake. With sleek design, high ceilings, and a rooftop deck with panoramic views of the lake, this property offers a perfect blend of style and sophistication.",
#     "listings_neighborhood_description": "Silver Lake is a trendy neighborhood known for its hip cafes, art galleries, and scenic lake views. Embrace the vibrant energy and creative spirit of this eclectic community."
# },
# {
#     "listings_headline": "Charming Cottage in Willowbrook Village",
#     "listings_neighborhood": "Willowbrook Village",
#     "listings_price": 1400000,
#     "listings_bedrooms": 2,
#     "listings_bathrooms": 1,
#     "listings_house_size": 150,
#     "listings_description": "Escape to this charming cottage in the heart of Willowbrook Village. With 2 bedrooms, 1 bathroom, a cozy fireplace, and a flower-filled garden, this property offers a perfect retreat for those seeking a peaceful lifestyle.",
#     "listings_neighborhood_description": "Willowbrook Village is a quaint village with historic cottages, local bakeries, and community events. Enjoy a sense of nostalgia and small-town charm in this idyllic setting."
# },
# {
#     "listings_headline": "Luxury Living in Diamond Heights",
#     "listings_neighborhood": "Diamond Heights",
#     "listings_price": 2700000,
#     "listings_bedrooms": 4,
#     "listings_bathrooms": 3,
#     "listings_house_size": 230,
#     "listings_description": "Indulge in luxury living in this 4-bedroom, 3-bathroom home in Diamond Heights. With high-end finishes, a gourmet kitchen, and a landscaped backyard with a pool, this property offers the ultimate in upscale living.",
#     "listings_neighborhood_description": "Diamond Heights is an exclusive neighborhood known for its luxury estates, private tennis clubs, and panoramic views. Experience privacy and sophistication in this prestigious enclave."
# },
# {
#     "listings_headline": "Tranquil Retreat in Cedar Valley",
#     "listings_neighborhood": "Cedar Valley",
#     "listings_price": 1600000,
#     "listings_bedrooms": 3,
#     "listings_bathrooms": 2,
#     "listings_house_size": 170,
#     "listings_description": "Find peace and tranquility in this 3-bedroom, 2-bathroom home in Cedar Valley. Surrounded by cedar trees, with a wrap-around porch and a meditation garden, this property offers a serene retreat in a natural setting.",
#     "listings_neighborhood_description": "Cedar Valley is a peaceful neighborhood with hiking trails, nature reserves, and a strong sense of community. Enjoy the beauty of the outdoors and a slower pace of life in this idyllic enclave."
# },
# {
#     "listings_headline": "Urban Oasis in City Center",
#     "listings_neighborhood": "City Center",
#     "listings_price": 2500000,
#     "listings_bedrooms": 4,
#     "listings_bathrooms": 3,
#     "listings_house_size": 260,
#     "listings_description": "Discover an urban oasis in the heart of the City Center. This 4-bedroom, 3-bathroom home features modern design, a rooftop terrace with city views, and a home office, offering a perfect blend of style and functionality.",
#     "listings_neighborhood_description": "City Center is a vibrant urban hub with shopping centers, restaurants, and cultural attractions. Experience the convenience and excitement of city living in this bustling neighborhood."
# }

# %%
property_listings = {}
for i, desc in enumerate(eval(response.choices[0].message['content'][:-2].replace('\n', ''))):
    property_listings[i] = desc

# %%
for i, listing in property_listings.items():
    print(YELLOW + f"Property {str(i)} : {listing['listings_headline']}" + ENDC)
    for key in list(listings_description_model.model_fields.keys())[1:]:
        print(f'- {key.split("listings_")[1].replace("_"," "):<25} : {listing[key]}')
    print('-------------------------------------------------')
# Out:
# Property 0 : Modern Luxury in Central Park
# - neighborhood              : Central Park
# - price                     : 3500000
# - bedrooms                  : 4
# - bathrooms                 : 3
# - house size                : 280
# - description               : Indulge in the epitome of modern luxury with this stunning 4-bedroom, 3-bathroom home in Central Park. Boasting high-end finishes, a gourmet kitchen, and panoramic views of the city skyline, this property offers a sophisticated urban lifestyle.
# - neighborhood description  : Central Park is a vibrant neighborhood known for its upscale dining, shopping, and cultural attractions. Enjoy easy access to the park for leisurely strolls and outdoor activities.
# -------------------------------------------------
# Property 1 : Seaside Retreat in Ocean View
# - neighborhood              : Ocean View
# - price                     : 1800000
# - bedrooms                  : 3
# - bathrooms                 : 2
# - house size                : 200
# - description               : Escape to this charming seaside retreat in Ocean View. With 3 bedrooms, 2 bathrooms, and a spacious deck overlooking the ocean, this home offers a perfect blend of coastal living and modern comfort.
# - neighborhood description  : Ocean View is a picturesque coastal community with sandy beaches, seafood restaurants, and a laid-back atmosphere. Experience the tranquility of seaside living in this charming neighborhood.
# -------------------------------------------------
# Property 2 : Historic Elegance in Heritage District
# - neighborhood              : Heritage District
# - price                     : 1200000
# - bedrooms                  : 5
# - bathrooms                 : 4
# - house size                : 320
# - description               : Step back in time with this historic 5-bedroom, 4-bathroom home in the Heritage District. Featuring elegant architecture, a grand staircase, and a beautifully landscaped garden, this property exudes timeless charm.
# - neighborhood description  : The Heritage District is a historic neighborhood filled with tree-lined streets, heritage homes, and boutique shops. Immerse yourself in the rich history and architectural beauty of this unique district.
# -------------------------------------------------
# Property 3 : Contemporary Living in Skyline Heights
# - neighborhood              : Skyline Heights
# - price                     : 2800000
# - bedrooms                  : 6
# - bathrooms                 : 5
# - house size                : 400
# - description               : Experience contemporary living at its finest in this 6-bedroom, 5-bathroom home in Skyline Heights. With sleek design, high ceilings, and a rooftop terrace with city views, this property is perfect for modern urban dwellers.
# - neighborhood description  : Skyline Heights offers a vibrant urban lifestyle with trendy cafes, art galleries, and easy access to public transportation. Enjoy the bustling energy of the city from the comfort of your stylish home.
# -------------------------------------------------
# Property 4 : Tranquil Haven in Willow Creek
# - neighborhood              : Willow Creek
# - price                     : 1500000
# - bedrooms                  : 4
# - bathrooms                 : 3
# - house size                : 250
# - description               : Find peace and serenity in this tranquil 4-bedroom, 3-bathroom home in Willow Creek. Surrounded by lush greenery, with a private backyard and a cozy fireplace, this property offers a perfect retreat from the hustle and bustle of city life.
# - neighborhood description  : Willow Creek is a quiet residential neighborhood known for its tree-lined streets, parks, and family-friendly atmosphere. Enjoy a sense of community and nature in this peaceful enclave.
# -------------------------------------------------
# Property 5 : Urban Chic in Downtown District
# - neighborhood              : Downtown District
# - price                     : 2000000
# - bedrooms                  : 3
# - bathrooms                 : 2
# - house size                : 180
# - description               : Embrace urban chic living in this stylish 3-bedroom, 2-bathroom home in the heart of the Downtown District. With modern design, high-end appliances, and a rooftop patio for entertaining, this property is perfect for those who love city living.
# - neighborhood description  : The Downtown District is a bustling urban center with a vibrant nightlife, trendy restaurants, and cultural attractions. Experience the excitement of city life right outside your doorstep.
# -------------------------------------------------
# Property 6 : Rustic Charm in Maple Grove
# - neighborhood              : Maple Grove
# - price                     : 1300000
# - bedrooms                  : 4
# - bathrooms                 : 3
# - house size                : 220
# - description               : Discover the rustic charm of this 4-bedroom, 3-bathroom home in Maple Grove. With exposed wooden beams, a cozy fireplace, and a spacious backyard with a fire pit, this property offers a warm and inviting atmosphere.
# - neighborhood description  : Maple Grove is a quaint neighborhood with tree-lined streets, local cafes, and boutique shops. Enjoy a sense of community and small-town charm in this cozy enclave.
# -------------------------------------------------
# Property 7 : Luxurious Retreat in Hillside Manor
# - neighborhood              : Hillside Manor
# - price                     : 3000000
# - bedrooms                  : 5
# - bathrooms                 : 4
# - house size                : 350
# - description               : Escape to a luxurious retreat in the prestigious Hillside Manor. This 5-bedroom, 4-bathroom home features a gourmet kitchen, a home theater, and a landscaped garden with a pool, offering the ultimate in upscale living.
# - neighborhood description  : Hillside Manor is an exclusive neighborhood known for its luxury estates, private golf courses, and scenic views. Enjoy privacy and sophistication in this upscale enclave.
# -------------------------------------------------
# Property 8 : Coastal Living in Seaview Heights
# - neighborhood              : Seaview Heights
# - price                     : 2200000
# - bedrooms                  : 3
# - bathrooms                 : 2
# - house size                : 190
# - description               : Experience the beauty of coastal living in this 3-bedroom, 2-bathroom home in Seaview Heights. With ocean views, a sun-drenched deck, and beach access just steps away, this property offers a perfect seaside retreat.
# - neighborhood description  : Seaview Heights is a coastal community with sandy beaches, seaside cafes, and water sports activities. Enjoy the laid-back lifestyle and stunning ocean views in this charming neighborhood.
# -------------------------------------------------
# Property 9 : Elegant Oasis in Rosewood Estates
# - neighborhood              : Rosewood Estates
# - price                     : 2600000
# - bedrooms                  : 4
# - bathrooms                 : 3
# - house size                : 240
# - description               : Discover an elegant oasis in the prestigious Rosewood Estates. This 4-bedroom, 3-bathroom home features a grand foyer, a gourmet kitchen, and a landscaped backyard with a fountain, offering a perfect blend of luxury and sophistication.
# - neighborhood description  : Rosewood Estates is an upscale neighborhood known for its luxury homes, private estates, and exclusive country clubs. Experience the epitome of luxury living in this prestigious enclave.
# -------------------------------------------------
# Property 10 : Serenity in Pinecrest Meadows
# - neighborhood              : Pinecrest Meadows
# - price                     : 1700000
# - bedrooms                  : 5
# - bathrooms                 : 4
# - house size                : 260
# - description               : Find serenity in this 5-bedroom, 4-bathroom home in Pinecrest Meadows. Surrounded by towering pine trees, with a wrap-around porch and a cozy fireplace, this property offers a peaceful retreat in a natural setting.
# - neighborhood description  : Pinecrest Meadows is a nature lover's paradise with hiking trails, wildlife, and scenic views. Enjoy the tranquility and beauty of the outdoors in this idyllic neighborhood.
# -------------------------------------------------
# Property 11 : Modern Elegance in Silver Lake
# - neighborhood              : Silver Lake
# - price                     : 1900000
# - bedrooms                  : 3
# - bathrooms                 : 2
# - house size                : 210
# - description               : Experience modern elegance in this 3-bedroom, 2-bathroom home in Silver Lake. With sleek design, high ceilings, and a rooftop deck with panoramic views of the lake, this property offers a perfect blend of style and sophistication.
# - neighborhood description  : Silver Lake is a trendy neighborhood known for its hip cafes, art galleries, and scenic lake views. Embrace the vibrant energy and creative spirit of this eclectic community.
# -------------------------------------------------
# Property 12 : Charming Cottage in Willowbrook Village
# - neighborhood              : Willowbrook Village
# - price                     : 1400000
# - bedrooms                  : 2
# - bathrooms                 : 1
# - house size                : 150
# - description               : Escape to this charming cottage in the heart of Willowbrook Village. With 2 bedrooms, 1 bathroom, a cozy fireplace, and a flower-filled garden, this property offers a perfect retreat for those seeking a peaceful lifestyle.
# - neighborhood description  : Willowbrook Village is a quaint village with historic cottages, local bakeries, and community events. Enjoy a sense of nostalgia and small-town charm in this idyllic setting.
# -------------------------------------------------
# Property 13 : Luxury Living in Diamond Heights
# - neighborhood              : Diamond Heights
# - price                     : 2700000
# - bedrooms                  : 4
# - bathrooms                 : 3
# - house size                : 230
# - description               : Indulge in luxury living in this 4-bedroom, 3-bathroom home in Diamond Heights. With high-end finishes, a gourmet kitchen, and a landscaped backyard with a pool, this property offers the ultimate in upscale living.
# - neighborhood description  : Diamond Heights is an exclusive neighborhood known for its luxury estates, private tennis clubs, and panoramic views. Experience privacy and sophistication in this prestigious enclave.
# -------------------------------------------------
# Property 14 : Tranquil Retreat in Cedar Valley
# - neighborhood              : Cedar Valley
# - price                     : 1600000
# - bedrooms                  : 3
# - bathrooms                 : 2
# - house size                : 170
# - description               : Find peace and tranquility in this 3-bedroom, 2-bathroom home in Cedar Valley. Surrounded by cedar trees, with a wrap-around porch and a meditation garden, this property offers a serene retreat in a natural setting.
# - neighborhood description  : Cedar Valley is a peaceful neighborhood with hiking trails, nature reserves, and a strong sense of community. Enjoy the beauty of the outdoors and a slower pace of life in this idyllic enclave.
# -------------------------------------------------
# Property 15 : Urban Oasis in City Center
# - neighborhood              : City Center
# - price                     : 2500000
# - bedrooms                  : 4
# - bathrooms                 : 3
# - house size                : 260
# - description               : Discover an urban oasis in the heart of the City Center. This 4-bedroom, 3-bathroom home features modern design, a rooftop terrace with city views, and a home office, offering a perfect blend of style and functionality.
# - neighborhood description  : City Center is a vibrant urban hub with shopping centers, restaurants, and cultural attractions. Experience the convenience and excitement of city living in this bustling neighborhood.
# -------------------------------------------------

# %% [markdown]
# - save the synthetic listing descriptions
# - we concatenate the descriptions in one column

# %%
df = pd.DataFrame(property_listings).T
df['full_description'] = df.apply(lambda x: x['listings_headline'] + ': ' + x['listings_description'] + ' Neighborhood: ' + x['listings_neighborhood_description'], axis=1)
df.to_csv('data/property_listings.csv', index=False, header=True)
df.to_json('data/property_listings.json', orient='records')
df
# Out:
#                           listings_headline listings_neighborhood  \
# 0             Modern Luxury in Central Park          Central Park
# 1             Seaside Retreat in Ocean View            Ocean View
# 2    Historic Elegance in Heritage District     Heritage District
# 3    Contemporary Living in Skyline Heights       Skyline Heights
# 4            Tranquil Haven in Willow Creek          Willow Creek
# 5           Urban Chic in Downtown District     Downtown District
# 6               Rustic Charm in Maple Grove           Maple Grove
# 7       Luxurious Retreat in Hillside Manor        Hillside Manor
# 8         Coastal Living in Seaview Heights       Seaview Heights
# 9         Elegant Oasis in Rosewood Estates      Rosewood Estates
# 10            Serenity in Pinecrest Meadows     Pinecrest Meadows
# 11           Modern Elegance in Silver Lake           Silver Lake
# 12  Charming Cottage in Willowbrook Village   Willowbrook Village
# 13         Luxury Living in Diamond Heights       Diamond Heights
# 14         Tranquil Retreat in Cedar Valley          Cedar Valley
# 15               Urban Oasis in City Center           City Center
#
#    listings_price listings_bedrooms listings_bathrooms listings_house_size  \
# 0         3500000                 4                  3                 280
# 1         1800000                 3                  2                 200
# 2         1200000                 5                  4                 320
# 3         2800000                 6                  5                 400
# 4         1500000                 4                  3                 250
# 5         2000000                 3                  2                 180
# 6         1300000                 4                  3                 220
# 7         3000000                 5                  4                 350
# 8         2200000                 3                  2                 190
# 9         2600000                 4                  3                 240
# 10        1700000                 5                  4                 260
# 11        1900000                 3                  2                 210
# 12        1400000                 2                  1                 150
# 13        2700000                 4                  3                 230
# 14        1600000                 3                  2                 170
# 15        2500000                 4                  3                 260
#
#                                  listings_description  \
# 0   Indulge in the epitome of modern luxury with t...
# 1   Escape to this charming seaside retreat in Oce...
# 2   Step back in time with this historic 5-bedroom...
# 3   Experience contemporary living at its finest i...
# 4   Find peace and serenity in this tranquil 4-bed...
# 5   Embrace urban chic living in this stylish 3-be...
# 6   Discover the rustic charm of this 4-bedroom, 3...
# 7   Escape to a luxurious retreat in the prestigio...
# 8   Experience the beauty of coastal living in thi...
# 9   Discover an elegant oasis in the prestigious R...
# 10  Find serenity in this 5-bedroom, 4-bathroom ho...
# 11  Experience modern elegance in this 3-bedroom, ...
# 12  Escape to this charming cottage in the heart o...
# 13  Indulge in luxury living in this 4-bedroom, 3-...
# 14  Find peace and tranquility in this 3-bedroom, ...
# 15  Discover an urban oasis in the heart of the Ci...
#
#                     listings_neighborhood_description  \
# 0   Central Park is a vibrant neighborhood known f...
# 1   Ocean View is a picturesque coastal community ...
# 2   The Heritage District is a historic neighborho...
# 3   Skyline Heights offers a vibrant urban lifesty...
# 4   Willow Creek is a quiet residential neighborho...
# 5   The Downtown District is a bustling urban cent...
# 6   Maple Grove is a quaint neighborhood with tree...
# 7   Hillside Manor is an exclusive neighborhood kn...
# 8   Seaview Heights is a coastal community with sa...
# 9   Rosewood Estates is an upscale neighborhood kn...
# 10  Pinecrest Meadows is a nature lover's paradise...
# 11  Silver Lake is a trendy neighborhood known for...
# 12  Willowbrook Village is a quaint village with h...
# 13  Diamond Heights is an exclusive neighborhood k...
# 14  Cedar Valley is a peaceful neighborhood with h...
# 15  City Center is a vibrant urban hub with shoppi...
#
#                                      full_description
# 0   Modern Luxury in Central Park: Indulge in the ...
# 1   Seaside Retreat in Ocean View: Escape to this ...
# 2   Historic Elegance in Heritage District: Step b...
# 3   Contemporary Living in Skyline Heights: Experi...
# 4   Tranquil Haven in Willow Creek: Find peace and...
# 5   Urban Chic in Downtown District: Embrace urban...
# 6   Rustic Charm in Maple Grove: Discover the rust...
# 7   Luxurious Retreat in Hillside Manor: Escape to...
# 8   Coastal Living in Seaview Heights: Experience ...
# 9   Elegant Oasis in Rosewood Estates: Discover an...
# 10  Serenity in Pinecrest Meadows: Find serenity i...
# 11  Modern Elegance in Silver Lake: Experience mod...
# 12  Charming Cottage in Willowbrook Village: Escap...
# 13  Luxury Living in Diamond Heights: Indulge in l...
# 14  Tranquil Retreat in Cedar Valley: Find peace a...
# 15  Urban Oasis in City Center: Discover an urban ...

# %%
#export DataFrame to text file
'''with open('./data/listings.txt', 'w') as f:
    df_string = df.to_string(header=True, index=True)
    f.write(df_string)'''

# %% [markdown]
# # STEP 2 - POPULATE VECTORSTORE WITH SYNTHETIC LISTINGS

# %%
'''loader = CSVLoader(file_path='data/property_listings.csv') #, metadata_columns=df.columns.tolist()
docs = loader.load()
print(f'Number of properties: {len(docs)}')
print(docs[0].page_content)'''
print()

# %% [markdown]
# PREPARE DATA FOR EMBEDDING STEP
# - JSONLoader from langchain requires jq package not available on windows.
# - We define a specific JSONLoader to capture the metadata of the JSON file
# - code from here: https://github.com/langchain-ai/langchain/issues/4396

# %%
import json
from pathlib import Path
from typing import Callable, Dict, List, Optional, Union

from langchain.docstore.document import Document
from langchain.document_loaders.base import BaseLoader

class JSONLoader(BaseLoader):
    def __init__(
        self,
        file_path: Union[str, Path],
        content_key: Optional[str] = None,
        metadata_func: Optional[Callable[[dict, dict], dict]] = None,
    ):
        """
        Initializes the JSONLoader with a file path, an optional content key to extract specific content,
        and an optional metadata function to extract metadata from each record.
        """
        self.file_path = Path(file_path).resolve()
        self.content_key = content_key 
        self.metadata_func = metadata_func

    def create_documents(self, processed_data):
        """
        Creates Document objects from processed data.
        """
        documents = []
        for item in processed_data:
            content = item.get('content', '')  
            metadata = item.get('metadata', {})
            document = Document(page_content=content, metadata=metadata)
            documents.append(document)
        return documents

    def process_json(self, data):
        """
        Processes JSON data to prepare for document creation, extracting content based on the content_key
        and applying the metadata function if provided.
        """
        processed_data = []
        if isinstance(data, list):
            for item in data:
                content = item.get(self.content_key, '') if self.content_key else ''
                metadata = {}
                if self.metadata_func and isinstance(item, dict):
                    metadata = self.metadata_func(item, {})
                processed_data.append({'content': content, 'metadata': metadata})
        return processed_data

    def load(self) -> List[Document]:
        """
        Load and return documents from the JSON file.
        """
        docs = []
        with open(self.file_path, mode="r", encoding="utf-8") as json_file:
            try:
                data = json.load(json_file)
                processed_json = self.process_json(data)
                docs = self.create_documents(processed_json)
            except json.JSONDecodeError:
                print("Error: Invalid JSON format in the file.")
        return docs

# %% [markdown]
# - we will use the combined description for the semantic search
# - we will use price, # rooms, house size and neighborhood in the metadata for easier, more accurate 'keyword' search

# %%
def metadata_func(item, _):
    return {
            'neighborhood':item['listings_neighborhood'],
            'price': item['listings_price'],
            'bedrooms':item['listings_bedrooms'],
            'bathrooms':item['listings_bathrooms'],
            'house size':item['listings_house_size'],
            }

json_loader= JSONLoader('data/property_listings.json',content_key='full_description', metadata_func=metadata_func)
docs = json_loader.load()
docs
# Out:
# [Document(page_content='Modern Luxury in Central Park: Indulge in the epitome of modern luxury with this stunning 4-bedroom, 3-bathroom home in Central Park. Boasting high-end finishes, a gourmet kitchen, and panoramic views of the city skyline, this property offers a sophisticated urban lifestyle. Neighborhood: Central Park is a vibrant neighborhood known for its upscale dining, shopping, and cultural attractions. Enjoy easy access to the park for leisurely strolls and outdoor activities.', metadata={'neighborhood': 'Central Park', 'price': 3500000, 'bedrooms': 4, 'bathrooms': 3, 'house size': 280}),
#  Document(page_content='Seaside Retreat in Ocean View: Escape to this charming seaside retreat in Ocean View. With 3 bedrooms, 2 bathrooms, and a spacious deck overlooking the ocean, this home offers a perfect blend of coastal living and modern comfort. Neighborhood: Ocean View is a picturesque coastal community with sandy beaches, seafood restaurants, and a laid-back atmosphere. Experience the tranquility of seaside living in this charming neighborhood.', metadata={'neighborhood': 'Ocean View', 'price': 1800000, 'bedrooms': 3, 'bathrooms': 2, 'house size': 200}),
#  Document(page_content='Historic Elegance in Heritage District: Step back in time with this historic 5-bedroom, 4-bathroom home in the Heritage District. Featuring elegant architecture, a grand staircase, and a beautifully landscaped garden, this property exudes timeless charm. Neighborhood: The Heritage District is a historic neighborhood filled with tree-lined streets, heritage homes, and boutique shops. Immerse yourself in the rich history and architectural beauty of this unique district.', metadata={'neighborhood': 'Heritage District', 'price': 1200000, 'bedrooms': 5, 'bathrooms': 4, 'house size': 320}),
#  Document(page_content='Contemporary Living in Skyline Heights: Experience contemporary living at its finest in this 6-bedroom, 5-bathroom home in Skyline Heights. With sleek design, high ceilings, and a rooftop terrace with city views, this property is perfect for modern urban dwellers. Neighborhood: Skyline Heights offers a vibrant urban lifestyle with trendy cafes, art galleries, and easy access to public transportation. Enjoy the bustling energy of the city from the comfort of your stylish home.', metadata={'neighborhood': 'Skyline Heights', 'price': 2800000, 'bedrooms': 6, 'bathrooms': 5, 'house size': 400}),
#  Document(page_content='Tranquil Haven in Willow Creek: Find peace and serenity in this tranquil 4-bedroom, 3-bathroom home in Willow Creek. Surrounded by lush greenery, with a private backyard and a cozy fireplace, this property offers a perfect retreat from the hustle and bustle of city life. Neighborhood: Willow Creek is a quiet residential neighborhood known for its tree-lined streets, parks, and family-friendly atmosphere. Enjoy a sense of community and nature in this peaceful enclave.', metadata={'neighborhood': 'Willow Creek', 'price': 1500000, 'bedrooms': 4, 'bathrooms': 3, 'house size': 250}),
#  Document(page_content='Urban Chic in Downtown District: Embrace urban chic living in this stylish 3-bedroom, 2-bathroom home in the heart of the Downtown District. With modern design, high-end appliances, and a rooftop patio for entertaining, this property is perfect for those who love city living. Neighborhood: The Downtown District is a bustling urban center with a vibrant nightlife, trendy restaurants, and cultural attractions. Experience the excitement of city life right outside your doorstep.', metadata={'neighborhood': 'Downtown District', 'price': 2000000, 'bedrooms': 3, 'bathrooms': 2, 'house size': 180}),
#  Document(page_content='Rustic Charm in Maple Grove: Discover the rustic charm of this 4-bedroom, 3-bathroom home in Maple Grove. With exposed wooden beams, a cozy fireplace, and a spacious backyard with a fire pit, this property offers a warm and inviting atmosphere. Neighborhood: Maple Grove is a quaint neighborhood with tree-lined streets, local cafes, and boutique shops. Enjoy a sense of community and small-town charm in this cozy enclave.', metadata={'neighborhood': 'Maple Grove', 'price': 1300000, 'bedrooms': 4, 'bathrooms': 3, 'house size': 220}),
#  Document(page_content='Luxurious Retreat in Hillside Manor: Escape to a luxurious retreat in the prestigious Hillside Manor. This 5-bedroom, 4-bathroom home features a gourmet kitchen, a home theater, and a landscaped garden with a pool, offering the ultimate in upscale living. Neighborhood: Hillside Manor is an exclusive neighborhood known for its luxury estates, private golf courses, and scenic views. Enjoy privacy and sophistication in this upscale enclave.', metadata={'neighborhood': 'Hillside Manor', 'price': 3000000, 'bedrooms': 5, 'bathrooms': 4, 'house size': 350}),
#  Document(page_content='Coastal Living in Seaview Heights: Experience the beauty of coastal living in this 3-bedroom, 2-bathroom home in Seaview Heights. With ocean views, a sun-drenched deck, and beach access just steps away, this property offers a perfect seaside retreat. Neighborhood: Seaview Heights is a coastal community with sandy beaches, seaside cafes, and water sports activities. Enjoy the laid-back lifestyle and stunning ocean views in this charming neighborhood.', metadata={'neighborhood': 'Seaview Heights', 'price': 2200000, 'bedrooms': 3, 'bathrooms': 2, 'house size': 190}),
#  Document(page_content='Elegant Oasis in Rosewood Estates: Discover an elegant oasis in the prestigious Rosewood Estates. This 4-bedroom, 3-bathroom home features a grand foyer, a gourmet kitchen, and a landscaped backyard with a fountain, offering a perfect blend of luxury and sophistication. Neighborhood: Rosewood Estates is an upscale neighborhood known for its luxury homes, private estates, and exclusive country clubs. Experience the epitome of luxury living in this prestigious enclave.', metadata={'neighborhood': 'Rosewood Estates', 'price': 2600000, 'bedrooms': 4, 'bathrooms': 3, 'house size': 240}),
#  Document(page_content="Serenity in Pinecrest Meadows: Find serenity in this 5-bedroom, 4-bathroom home in Pinecrest Meadows. Surrounded by towering pine trees, with a wrap-around porch and a cozy fireplace, this property offers a peaceful retreat in a natural setting. Neighborhood: Pinecrest Meadows is a nature lover's paradise with hiking trails, wildlife, and scenic views. Enjoy the tranquility and beauty of the outdoors in this idyllic neighborhood.", metadata={'neighborhood': 'Pinecrest Meadows', 'price': 1700000, 'bedrooms': 5, 'bathrooms': 4, 'house size': 260}),
#  Document(page_content='Modern Elegance in Silver Lake: Experience modern elegance in this 3-bedroom, 2-bathroom home in Silver Lake. With sleek design, high ceilings, and a rooftop deck with panoramic views of the lake, this property offers a perfect blend of style and sophistication. Neighborhood: Silver Lake is a trendy neighborhood known for its hip cafes, art galleries, and scenic lake views. Embrace the vibrant energy and creative spirit of this eclectic community.', metadata={'neighborhood': 'Silver Lake', 'price': 1900000, 'bedrooms': 3, 'bathrooms': 2, 'house size': 210}),
#  Document(page_content='Charming Cottage in Willowbrook Village: Escape to this charming cottage in the heart of Willowbrook Village. With 2 bedrooms, 1 bathroom, a cozy fireplace, and a flower-filled garden, this property offers a perfect retreat for those seeking a peaceful lifestyle. Neighborhood: Willowbrook Village is a quaint village with historic cottages, local bakeries, and community events. Enjoy a sense of nostalgia and small-town charm in this idyllic setting.', metadata={'neighborhood': 'Willowbrook Village', 'price': 1400000, 'bedrooms': 2, 'bathrooms': 1, 'house size': 150}),
#  Document(page_content='Luxury Living in Diamond Heights: Indulge in luxury living in this 4-bedroom, 3-bathroom home in Diamond Heights. With high-end finishes, a gourmet kitchen, and a landscaped backyard with a pool, this property offers the ultimate in upscale living. Neighborhood: Diamond Heights is an exclusive neighborhood known for its luxury estates, private tennis clubs, and panoramic views. Experience privacy and sophistication in this prestigious enclave.', metadata={'neighborhood': 'Diamond Heights', 'price': 2700000, 'bedrooms': 4, 'bathrooms': 3, 'house size': 230}),
#  Document(page_content='Tranquil Retreat in Cedar Valley: Find peace and tranquility in this 3-bedroom, 2-bathroom home in Cedar Valley. Surrounded by cedar trees, with a wrap-around porch and a meditation garden, this property offers a serene retreat in a natural setting. Neighborhood: Cedar Valley is a peaceful neighborhood with hiking trails, nature reserves, and a strong sense of community. Enjoy the beauty of the outdoors and a slower pace of life in this idyllic enclave.', metadata={'neighborhood': 'Cedar Valley', 'price': 1600000, 'bedrooms': 3, 'bathrooms': 2, 'house size': 170}),
#  Document(page_content='Urban Oasis in City Center: Discover an urban oasis in the heart of the City Center. This 4-bedroom, 3-bathroom home features modern design, a rooftop terrace with city views, and a home office, offering a perfect blend of style and functionality. Neighborhood: City Center is a vibrant urban hub with shopping centers, restaurants, and cultural attractions. Experience the convenience and excitement of city living in this bustling neighborhood.', metadata={'neighborhood': 'City Center', 'price': 2500000, 'bedrooms': 4, 'bathrooms': 3, 'house size': 260})]

# %% [markdown]
# - For demonstration purpose we implement a text splitter. However to ensure semantic search we embed the full description as a whole since it is of limited size anyhow

# %%
'''# Splitter to chunk text into smaller chunks
text_splitter = CharacterTextSplitter(
    separator="\n\n",
    chunk_size=200,
    chunk_overlap=20,
    length_function=len,
    is_separator_regex=False,
)

split_docs = text_splitter.split_documents(docs)

# embed each chunk and load it into the vector store.
db = Chroma.from_documents(split_docs, OpenAIEmbeddings())'''
print()

# %% [markdown]
# ### RUBRIC #2 Creating a Vector Database and Storing Listings

# %%
# we create a chromadb collection to store the listings, their embeddings and metadata
try:
    collection = client.get_collection(name="homematch", embedding_function=OpenAIEmbeddings())
except:
    collection = client.create_collection(name="homematch", embedding_function=OpenAIEmbeddings())

# %%
# we generate the ambeddings for each description using OpenAi Embedding model
embeddings = embeddings_model.embed_documents([doc.page_content for doc in docs])

# %%
# we add the data to the collection - this is automatically persisted to disk in the data/db folder
collection.add(
    documents=[doc.page_content for doc in docs],
    embeddings=embeddings,
    metadatas=[doc.metadata for doc in docs],
    ids=[str(i) for i in range(len(docs))] 
)

# %%
collection.count() # returns the number of items in the collection
# Out:
# 16

# %%
collection.peek(2) # returns a list of the first 2 items in the collection
# Out:
# {'ids': ['0', '1'],
#  'embeddings': [[0.012835898850191383,
#    0.023745753775894586,
#    -0.009729163328777135,
#    -0.013508695564182034,
#    0.0022014292466056174,
#    0.018007195759674403,
#    -0.014379373171587419,
#    0.0029847092188278394,
#    -0.03350789709835375,
#    -0.0130139919336614,
#    -0.0005907580833086552,
#    0.01776973831504771,
#    -0.022255047258125295,
#    -0.005339496553641952,
#    -0.0010479462375994788,
#    0.0002786828150790133,
#    0.0322414549101513,
#    -0.017505896502946375,
#    0.011490306353532613,
#    -0.02121287312477982,
#    -0.036805918818297874,
#    0.0114045576249013,
#    0.006371777247676338,
#    -0.011648611627057921,
#    -0.004933839930517597,
#    -0.0013662053419559895,
#    0.010843894007016602,
#    -0.008066960285067752,
#    0.011364982005011875,
#    0.0029962524960133116,
#    0.004854687293754943,
#    -0.0063289028833606814,
#    -0.027360386042889324,
#    -0.005398860914798625,
#    -0.00310014012803749,
#    -0.017756547062632928,
#    -0.004171997140453203,
#    -0.020988608795212985,
#    0.0076316214813650605,
#    -0.0032666901671526707,
#    0.013996802637172739,
#    -0.025289227165968084,
#    0.006787327775773049,
#    -0.0012928243437860722,
#    -0.009828103309823233,
#    -3.751499237864789e-05,
#    -6.462060731259697e-05,
#    -0.027967220906870836,
#    -0.0445364807463703,
#    -0.015975616227932737,
#    0.014352988804112777,
#    0.022334200360549217,
#    -0.023099341429378573,
#    -0.010672397481076512,
#    -0.01986728155944359,
#    -0.01240056051214996,
#    -0.02717569547056684,
#    0.0009712673099105484,
#    0.00999960076708586,
#    -0.02707015986331335,
#    -0.002958325084183833,
#    -0.023521487583682676,
#    -0.015883270010448956,
#    -0.002470218011193128,
#    -0.007552468844602408,
#    -0.008475915186957072,
#    -0.04543354178992779,
#    0.004185189324190523,
#    0.006906056498086396,
#    -0.0009325155612204628,
#    0.040103940538242,
#    0.007684389750653073,
#    0.0009564262196213801,
#    0.004139016681109902,
#    0.010995603654334518,
#    -0.017545473985480876,
#    -0.005890266266554294,
#    0.026872278038576083,
#    -0.0015418249491829196,
#    0.007783330197360439,
#    0.005042674747858586,
#    -0.03329682215855663,
#    -0.0061508097998906625,
#    0.025302420281027943,
#    0.02658205185900011,
#    0.027334001675414683,
#    -0.02546072462323071,
#    0.013970418269698099,
#    0.008541875174321137,
#    0.004152208864847223,
#    -0.012756746679089997,
#    -0.011345193263744627,
#    0.0011172047365591421,
#    0.007710774118127714,
#    -0.039549870683919616,
#    0.023587449433691815,
#    -0.0009902308994099707,
#    0.017439936515582313,
#    -0.008132920272431817,
#    0.017796122682522352,
#    0.009062962240993873,
#    0.003522286748002861,
#    -0.015777734403195468,
#    -0.011444134176113261,
#    -0.04187168012052741,
#    -0.010171098224348486,
#    0.01907575612313959,
#    -0.026344594414373416,
#    0.035697782834943265,
#    0.045407159285098225,
#    -0.017189287818540837,
#    0.01160903507584596,
#    0.024721967921875997,
#    -0.036489306408602186,
#    0.00700499741045503,
#    -0.0011510094163477327,
#    0.0027670398169764936,
#    -0.030711174635137655,
#    -0.011516690721007255,
#    0.010975814913067268,
#    0.008357186464643725,
#    0.015012593334366109,
#    0.027782532197193427,
#    0.010309614756606545,
#    -0.01239396395462003,
#    -0.0030457227193669946,
#    -0.004287427584001585,
#    -0.02944473430958027,
#    -0.04643614030338384,
#    0.003984009686349559,
#    -0.004854687293754943,
#    0.0025988408713094645,
#    0.024748352289350635,
#    -0.0034926045674245247,
#    -0.014735559338527457,
#    0.0100259851345605,
#    -0.0020431242059109444,
#    0.012994204123716688,
#    -0.0320831524305936,
#    -0.032821907269303244,
#    0.028521288898548144,
#    0.032452529849948425,
#    -0.011325405453799915,
#    0.030948632079764348,
#    0.013469119012970073,
#    0.005276834379381583,
#    0.0006888741931554139,
#    0.02923366123242822,
#    0.008700180447846444,
#    -0.008594643909270418,
#    0.00822526555859306,
#    -0.03664761261345003,
#    0.012690785760403394,
#    0.015724965668246185,
#    -0.012888667585140663,
#    0.018983411768300887,
#    -0.0008748001648232962,
#    0.01609434495024608,
#    -0.014933440231942187,
#    -0.0015748051756955862,
#    0.004247851498450892,
#    0.0042181693178725554,
#    -0.004373176312632898,
#    -0.0014272187260798276,
#    -0.009452129332938482,
#    0.012849091033928702,
#    0.017901660152420912,
#    0.028574057633497425,
#    -0.024748352289350635,
#    0.009729163328777135,
#    -0.004973416016068289,
#    0.025975216995018594,
#    -0.03147631756661209,
#    0.016147111822550287,
#    0.006952229141167017,
#    0.01776973831504771,
#    0.016965021626328926,
#    -0.007222666579475742,
#    -0.0035981413388311845,
#    -0.012360983960937998,
#    -0.0022459525174731224,
#    -0.006084849346865329,
#    0.0015113183153286592,
#    0.044879475660895556,
#    0.0016308716073332463,
#    0.004244553685347196,
#    0.035618631595164416,
#    -0.02939196557463099,
#    -0.004696382485890905,
#    -0.01419468353058747,
#    0.009735758954984526,
#    0.0018666800289927734,
#    0.023534680698742535,
#    -0.021476714936881153,
#    -0.6425073483710605,
#    -0.0009399361063650469,
#    -0.02083030259036514,
#    -0.020922646945203845,
#    0.030922247712289706,
#    0.030869478977340426,
#    0.014761943706002097,
#    0.02308615017696379,
#    -0.0004312163044924377,
#    -0.025671797700382765,
#    -0.0009152009364805469,
#    -0.005039376469093622,
#    -0.0003238244841111196,
#    0.004821707300072911,
#    -0.026357787529433272,
#    -0.010283230389131905,
#    0.0023234560148532937,
#    -0.013746153008808727,
#    -0.03171377501123878,
#    -0.006434439887597975,
#    0.014564061881264828,
#    0.02208355166350774,
#    -0.010296422572869224,
#    -0.016213073672559426,
#    -0.0046337198459692665,
#    0.005055866931595907,
#    0.019629822252171823,
#    -0.011299021086325274,
#    -0.012512692676933376,
#    -0.0017759844642905988,
#    -0.01201139342020535,
#    0.02730761730794004,
#    -0.0017199181490682558,
#    0.008376974274588438,
#    0.04572376796950376,
#    -0.0248143122767147,
#    -0.03018349101093499,
#    0.024906656631553406,
#    -0.004587547668549914,
#    0.030684790267663013,
#    -0.005032780377224962,
#    0.012908455395085375,
#    0.01402318700464738,
#    0.001444533409027402,
#    0.005075654741540619,
#    0.018943834285766386,
#    0.02743953728266817,
#    -0.010725165284703256,
#    0.004221467130976251,
#    0.001073505918967561,
#    0.022716770894963895,
#    -0.007117130040899715,
#    -0.015738158783306044,
#    0.017994004507259617,
#    0.004092844503690549,
#    -0.005408754819770981,
#    0.023297223254115842,
#    -0.010204078218030519,
#    0.018877874298402323,
#    -0.009076154424731194,
#    0.01817869321693703,
#    0.005527484007745595,
#    -0.014656407167426071,
#    -0.022123127283397166,
#    -0.012783131046564637,
#    0.03427303816718311,
#    -0.003792724651972854,
#    0.0023597342873002904,
#    -0.012545673601937946,
#    -0.022096742915922524,
#    -0.006655406869722383,
#    0.0243921661224106,
#    -0.014511294077638084,
#    -0.013917650466071354,
#    0.019339597935240923,
#    -0.0049305421174139,
#    0.032848293499422955,
#    -0.0191285229954438,
#    -0.013521887747919355,
#    0.008700180447846444,
#    0.013838497363647432,
#    -0.015883270010448956,
#    -0.022162702903286587,
#    -0.022479313450337202,
#    0.010448131288864604,
#    -0.014973016783154148,
#    -0.026674396213838814,
#    0.010085349495717173,
#    0.026555667491525468,
#    -0.014709174971052815,
#    0.013277833745762734,
#    0.0010355787399687166,
#    -0.010758145278385289,
#    -0.02224185600571051,
#    -0.03461603308170837,
#    0.018877874298402323,
#    0.004475415038105228,
#    0.02820467835149753,
#    -0.00701818959419235,
#    -0.02704377549583871,
#    -0.01185308907800258,
#    -0.0075062966671830544,
#    0.02780891656466807,
#    -0.005415350911639641,
#    0.02658205185900011,
#    0.0031133320789441758,
#    0.0007498875772792519,
#    0.030737559002612293,
#    0.03137078009671353,
#    -0.022479313450337202,
#    -0.02725484857299076,
#    -0.012835898850191383,
#    -0.016516491104550186,
#    -0.004300619767738905,
#    0.025302420281027943,
#    -0.021569059291719858,
#    -0.001965620708530773,
#    0.008647411712897162,
#    0.019115331743029016,
#    -0.00997321639961122,
#    0.001947481572307275,
#    -0.006401459428254675,
#    0.013680193021444662,
#    -0.014735559338527457,
#    0.009254247508201214,
#    0.002300369926143617,
#    0.023877673750622715,
#    -0.02367979378853052,
#    0.0017397063082589192,
#    0.0009506546392363026,
#    0.012862283217666023,
#    0.012209275244942619,
#    0.0382570459908876,
#    -0.0019013092784726051,
#    0.008436338635745111,
#    0.020632420765627872,
#    0.010962622729329949,
#    -0.02579052642269611,
#    0.014471717526426123,
#    -0.02208355166350774,
#    -0.03509094797096175,
#    0.010263442579187192,
#    -0.0037234661530131906,
#    0.0038125126947482005,
#    -0.00918828752083715,
#    -0.0006868129435502868,
#    -0.017954428887370196,
#    -0.009867679861035194,
#    -0.04651529154316269,
#    -0.009300420616943103,
#    -0.048837100979770474,
#    -0.015157706424154095,
#    -0.02949750304452955,
#    0.01645053111718612,
#    0.011556267272219216,
#    -0.005329602648669596,
#    0.01755866523789566,
#    -0.018732761208614335,
#    -0.012756746679089997,
#    -0.0104217478527125,
#    0.015395163868780789,
#    0.0006192035257654472,
#    -0.026120328222161506,
#    0.01722886343843026,
#    0.017730162695158286,
#    -0.010507495650021277,
#    0.009161903153362507,
#    0.0012581950943062405,
#    -0.004307215859607565,
#    -0.045486310524877074,
#    -0.0028165102731608107,
#    -0.014326604436638137,
#    -0.0132448537520807,
#    0.017255247805904903,
#    0.017994004507259617,
#    -0.0004378123381534394,
#    -0.0017116730342324306,
#    -0.03754467365700752,
#    -0.022505697817811844,
#    0.006124425432416022,
#    0.018165501964522247,
#    -0.0027521987266873253,
#    -0.037861286066703206,
#    -0.008964022259947777,
#    0.03234699238004986,
#    0.007433740122289061,
#    0.036515692638721904,
#    0.01699140599380357,
#    -0.004472116759340264,
#    0.011371577631219269,
#    0.028758746343174837,
#    0.020500500790899743,
#    -0.02191205420624511,
#    0.009287228433205784,
#    0.009122326602150546,
#    0.010665800923546583,
#    0.014735559338527457,
#    0.0004485309001285243,
#    0.0006629022851493693,
#    -0.005329602648669596,
#    0.0024372377846804618,
#    0.011905856881629324,
#    0.00781631065670374,
#    -0.026595244974059965,
#    0.027888067804446914,
#    -0.04102738408662905,
#    0.009894064228509834,
#    0.007150110500243017,
#    0.010355786934025897,
#    0.007552468844602408,
#    0.004135718868006206,
#    -0.005395563101694929,
#    -0.020474116423425105,
#    -0.008726564815321084,
#    0.0315818513112205,
#    0.029682191754206964,
#    0.015118129872942134,
#    0.025566262093129274,
#    0.00803398029138572,
#    -0.00939276497178181,
#    0.0325052985848977,
#    0.005306516559959919,
#    0.007486508391577074,
#    0.006312412886519665,
#    -0.04693744142275694,
#    0.011899261255421933,
#    -0.013099740662292714,
#    0.021410754949517087,
#    -0.012677594507988612,
#    -0.02730761730794004,
#    -0.02637097878184806,
#    0.035249250450519444,
#    0.021964822941194395,
#    0.00678073168390439,
#    -0.02023665897879841,
#    0.019933241546807656,
#    0.006549870331146357,
#    -0.024761543541765418,
#    0.017176094703480978,
#    -0.007070957863480363,
#    0.01820507758441167,
#    0.014959824599416829,
#    -0.0008286278709886263,
#    -0.019603439747342258,
#    -0.007499700575314395,
#    0.000472853814271233,
#    0.027914452171921556,
#    0.029893264831359016,
#    -0.004821707300072911,
#    0.004923946025545241,
#    -0.016503297989490327,
#    -0.01609434495024608,
#    -0.0032155708044165057,
#    0.012822706666454062,
#    0.004092844503690549,
#    -0.008317609913431764,
#    0.008139516829961746,
#    -0.013106337219822644,
#    0.012281831789836613,
#    0.03530201918546873,
#    0.0014412353630930718,
#    -0.025750950802806687,
#    0.019115331743029016,
#    -0.00918828752083715,
#    0.013469119012970073,
#    -0.0024372377846804618,
#    0.01617349619002493,
#    -0.042346595009780795,
#    0.01981451282449431,
#    0.00037247028329270767,
#    0.02077753385541586,
#    -0.028679593240750912,
#    0.032821907269303244,
#    -0.015883270010448956,
#    -0.020197083358908987,
#    -0.014748751522264776,
#    -0.0002743541443421197,
#    -0.012987608497509297,
#    -0.018495303763987645,
#    0.01652968235696497,
#    0.014471717526426123,
#    -0.010685588733491295,
#    0.013864881731122073,
#    0.012130122142518697,
#    0.0065069959668307,
#    -0.008330802097169085,
#    -0.010058965128242532,
#    0.01882510556345304,
#    0.02370617815600516,
#    0.04730681884211176,
#    0.02002558590164636,
#    0.010520687833758596,
#    -0.006216770252915995,
#    0.005741855363662611,
#    -0.002447131922483452,
#    -0.01817869321693703,
#    0.05144913287066409,
#    -0.012314811783518644,
#    0.0009819859009894626,
#    -0.03329682215855663,
#    -0.015250050778992802,
#    0.011312213270062595,
#    0.005385668731061304,
#    -0.00336233280075634,
#    -0.007651409756971041,
#    0.010547072201233238,
#    0.0037663402844982136,
#    0.0030984909886550074,
#    0.001070207873033231,
#    -0.028547673266022783,
#    0.00047656408684352506,
#    -0.01864041685377563,
#    -0.009854487677297873,
#    -0.011134120186592576,
#    -0.01647691548466076,
#    -0.009544473687777187,
#    -0.009471917142883193,
#    0.02443174174230002,
#    0.010329402566551257,
#    -0.030368179720612398,
#    -0.005534079633952987,
#    -0.03026264411335891,
#    -0.017782931430107566,
#    0.027334001675414683,
#    0.10817510198335484,
#    -0.013112932846030035,
#    0.005725364901160326,
#    0.03757105988712724,
#    0.0016828154233453352,
#    -0.006309115073415969,
#    -0.015184089860306199,
#    0.0006563062514883677,
#    0.013838497363647432,
#    0.011325405453799915,
#    0.005764941452372287,
#    -0.002288826881788779,
#    0.00042173448063889733,
#    0.005764941452372287,
#    0.009471917142883193,
#    -0.0004885194160439837,
#    -0.01994643279922244,
#    -0.04680551772273866,
#    -0.040024785573173,
#    -0.00246527105870695,
#    0.01980131970943445,
#    -0.003202378620679185,
#    0.003032530535629674,
#    0.030289028480833553,
#    -0.004125824497372582,
#    0.01400999482091006,
#    0.016054767467711582,
#    -0.007103937857162395,
#    0.017598242720430157,
#    -0.031106938284612192,
#    0.007849290650385773,
#    0.0007119603400727487,
#    -0.006833500418853671,
#    0.00025889468499217915,
#    -0.020276234598687836,
#    -0.0014206227506264844,
#    0.0017611433740014305,
#    -0.02240016034791328,
#    0.032109534935423165,
#    -0.0023580853807484425,
#    0.02579052642269611,
#    0.009307016243150494,
#    0.012380771770882709,
#    -0.004066460136215908,
#    0.010428343478919891,
#    0.0005643738904569901,
#    -0.010342594750288578,
#    0.03617269772419665,
#    0.006243154620390636,
#    0.011985009984053246,
#    0.006678493424093328,
#    0.004221467130976251,
#    -0.0008001824285318343,
#    -0.0005087198018726091,
#    0.03308575094404965,
#    -0.007935039379017086,
#    0.024009595587995917,
#    -0.02002558590164636,
#    -0.007981211556436439,
#    -0.030948632079764348,
#    0.00521087392635625,
#    -0.04348111349796497,
#    0.003403558025689515,
#    -0.007532680568996427,
#    -0.016687988561812812,
#    0.0021618529282242905,
#    -0.001016615034053977,
#    0.01747951399811681,
#    -0.03213592116554288,
#    -0.011820108152998011,
#    -0.0004062749921851275,
#    -0.0024883571474166267,
#    -0.0020348792074904366,
#    -0.010962622729329949,
#    0.03429942067201268,
#    -0.003792724651972854,
#    0.024128324310309264,
#    0.004943733835489952,
#    -0.009161903153362507,
#    0.03472157055160693,
#    0.007697581934390394,
#    -0.024101939942834626,
#    0.012888667585140663,
#    -0.007249050946950382,
#    0.00037741732309037353,
#    0.004244553685347196,
#    0.004689786394022244,
#    -0.0188382986785129,
#    -0.001223565961241726,
#    0.014405757539062059,
#    0.009102538792205834,
#    0.0019837598447542716,
#    0.01120667673148657,
#    0.03152908257627122,
#    -0.006375075060780034,
#    -0.017387167780633032,
#    -0.009069558798523803,
#    0.0036377176572125114,
#    0.017492705250531593,
#    -0.006840096510722331,
#    0.011978413426523319,
#    -0.010909854925703203,
#    0.004412752398183591,
#    -0.0046469120297065875,
#    0.0104217478527125,
#    -0.0027225165461089887,
#    -0.016371378014762197,
#    -0.0047359585714415965,
#    0.0002071569677471566,
#    0.023521487583682676,
#    0.015527084774831454,
#    -0.020764342603001078,
#    -0.010698780917228616,
#    0.014366180987850098,
#    -0.017519089618006235,
#    0.004096142316794245,
#    0.00012212985401099594,
#    0.02833660018887073,
#    0.010560264384970557,
#    -0.01598880748034752,
#    -0.015540276958568775,
#    -0.02561902896543348,
#    0.011872876887947293,
#    0.01882510556345304,
#    0.017703778327683644,
#    -0.0016399411754449956,
#    0.005543974004586612,
#    0.023323607621590484,
#    -0.006345392880201697,
#    0.007216070487607081,
#    -0.006919248681823716,
#    0.020817111337950358,
#    -0.02036857895352654,
#    -0.04572376796950376,
#    -0.0060386771694459765,
#    -0.010118329489399206,
#    -0.006741155598353697,
#    0.005692384907478294,
#    -0.018548072498936925,
#    -0.00904977098857909,
#    -0.025566262093129274,
#    0.01181351252679062,
#    -0.003993904056983184,
#    -0.01181351252679062,
#    0.003627823519409521,
#    -0.021661403646558563,
#    0.009828103309823233,
#    -0.034061963227385986,
#    -0.022769539629913176,
#    0.031186089524391038,
#    0.0003854562372957299,
#    0.006121127619312326,
#    0.0033804719369798387,
#    0.020144314623959707,
#    -0.0215954436591945,
#    -0.01085049056454653,
#    0.0024949532392852867,
#    -0.015289627330204763,
#    0.007130322224637036,
#    0.020302618966162474,
#    0.004966820389860897,
#    -0.014102339175748765,
#    0.0033227564823750137,
#    0.0030885970836826513,
#    0.010256846021657263,
#    0.009735758954984526,
#    -0.018614032486300988,
#    -0.0007049520797737851,
#    -0.009702778961302495,
#    0.022967421454650444,
#    0.01842934377662358,
#    0.01742674526316753,
#    0.00997321639961122,
#    -0.014141915726960726,
#    -0.02272996401002375,
#    0.03187207749079647,
#    0.00039658705501260607,
#    -0.010032580760767892,
#    -0.012334599593463356,
#    -0.01980131970943445,
#    -0.027492306017617454,
#    0.020540076410789167,
#    -0.05693704032719772,
#    -0.0013653808886800655,
#    -0.008594643909270418,
#    -0.005174595653909253,
#    0.02833660018887073,
#    0.009485109326620514,
#    0.007163302218319068,
#    -0.0023646812397864684,
#    0.00037391316383706243,
#    -0.040367780487698256,
#    0.02321807015169192,
#    0.01864041685377563,
#    0.010124925115606597,
#    0.00965660678388314,
#    0.008924445708735816,
#    -0.04337557602806641,
#    0.005880371895920669,
#    0.028521288898548144,
#    -0.0007395812710459583,
#    0.004175294953556899,
#    -0.016674795446752953,
#    -0.01877233682850376,
#    0.02815190961654825,
#    0.028547673266022783,
#    -0.0096302224164085,
#    -0.009689586777565174,
#    0.004881071661229584,
#    0.004231361501609876,
#    0.003502498705227515,
#    -0.014247452265536751,
#    -0.011477114169795294,
#    -0.035776934074722114,
#    0.006173895888600339,
#    0.008363782090851118,
#    0.0023036679720779473,
#    0.020592845145738448,
#    -0.028099142744244042,
#    0.004834899483810231,
#    0.02118648875730518,
#    -0.006282730705941329,
#    0.011450729802320652,
#    -0.013732960825071406,
#    0.0046601042134439075,
#    -0.005306516559959919,
#    -0.0016514842197998337,
#    0.017901660152420912,
#    0.017308016540854183,
#    -0.009788527689933808,
#    0.0023069660180122776,
#    0.017334400908328825,
#    0.006305816794651005,
#    0.01565900568088212,
#    -0.00782950284044106,
#    -0.007776734571153048,
#    -0.0028775235408693314,
#    -0.0197221684696556,
#    -0.0066685990534597036,
#    0.0480455736808214,
#    0.008825504796367182,
#    0.004109334500531566,
#    -0.020038777154061143,
#    0.0015261594056178273,
#    0.002283879696471967,
#    0.02447131922483452,
#    0.0020579652962001128,
#    0.019431942290079628,
#    -0.0044688189462365685,
#    0.007862482834123092,
#    -0.0300779554036815,
#    0.034800721791385776,
#    -0.00679392386764171,
#    0.015395163868780789,
#    -0.011147312370329896,
#    -0.045565461764655917,
#    -0.0020991905211332875,
#    -0.0035585650204498576,
#    -0.015421548236255429,
#    0.014247452265536751,
#    0.003068808808076671,
#    0.014326604436638137,
#    -0.011114332376647863,
#    -0.02316530141674264,
#    0.005576953998268644,
#    0.024075555575359984,
#    0.0022063761990917955,
#    0.015263242962730121,
#    0.002628523051887801,
#    0.023349991989065122,
#    -0.02108095315005169,
#    -0.0076448136651023815,
#    0.02741315291519353,
#    -0.005557166188323932,
#    0.004224765409741216,
#    -0.023455527596318613,
#    0.0004159629293576489,
#    -0.020869878210254565,
#    0.0035453730695431717,
#    -0.008706776074053835,
#    -0.009062962240993873,
#    -0.009504897136565226,
#    0.010870278374491242,
#    0.005534079633952987,
#    0.0028198083190951405,
#    0.0007519488850920375,
#    0.0011419398482359834,
#    -0.0014354638409156528,
#    0.01322506594213599,
#    -0.01606796058277144,
#    0.003931241417061546,
#    -0.034352189406961955,
#    -0.022848692732337098,
#    -0.007710774118127714,
#    -0.0019639718019789252,
#    0.004894263844966904,
#    -0.0035882472010281942,
#    0.013759345192546046,
#    -0.038125126016159465,
#    0.010190886034293198,
#    -0.007196282677662369,
#    0.01699140599380357,
#    -0.016569259839499466,
#    0.007737158019941087,
#    -0.0012557216180631514,
#    0.005138317381462257,
#    0.011674995994532561,
#    -0.007486508391577074,
#    -0.04899540345932817,
#    -0.03065840590018837,
#    -0.003020987491274836,
#    -0.028600442000972066,
#    0.008337397723376477,
#    -0.015909654377923597,
#    -0.01261163358930201,
#    -0.008535279548113745,
#    0.004386368496370219,
#    0.017980813254844834,
#    -0.03530201918546873,
#    0.01400999482091006,
#    0.0026318210978221314,
#    0.0008970618002570486,
#    0.02941834994210563,
#    0.01809954197715818,
#    0.03501179300589275,
#    -0.013455926829232754,
#    0.018310615054310232,
#    0.014577254065002149,
#    -0.02561902896543348,
#    -0.014102339175748765,
#    -0.017294823425794324,
#    0.01361423210275806,
#    0.006084849346865329,
#    -0.005313112186167311,
#    -0.003058914903104315,
#    0.0061508097998906625,
#    -0.011892664697892005,
#    0.02828383145392145,
#    0.019141716110503654,
#    -0.009623625858878573,
#    0.015091745505467494,
#    0.037016990032804856,
#    0.02641055440173748,
#    0.021753748001397268,
#    -0.0068466921369297225,
#    -0.016318609279812917,
#    -0.03218868990049216,
#    -0.02139756183445723,
#    -0.023956826853046637,
#    -0.04910094092922673,
#    -0.012176295251260587,
#    0.020790726970475716,
#    0.0029401859479603345,
#    -0.018033580127149042,
#    -0.005725364901160326,
#    0.008311013355901837,
#    -0.046093145388858586,
#    -0.02645013188427198,
#    0.008330802097169085,
#    0.013930842649808674,
#    0.021067760034991834,
#    0.025394764635866648,
#    -0.010250250395449871,
#    0.002114031611422456,
#    0.00819888119111842,
#    0.030420948455561682,
#    -0.02910174125770009,
#    0.03720168246777241,
#    0.018033580127149042,
#    -0.012736958869145285,
#    0.022611235287710408,
#    -0.018033580127149042,
#    -0.0015822257208401704,
#    -0.011074755825435902,
#    0.005349390458614308,
#    0.004145612772978562,
#    0.008950830076210456,
#    0.028917050685377605,
#    -0.003337597572664182,
#    0.009109135349735764,
#    -0.010547072201233238,
#    0.02069838261563701,
#    0.00041946708861096,
#    0.025104538456290675,
#    0.028574057633497425,
#    -0.023798522510843866,
#    -0.014933440231942187,
#    0.015012593334366109,
#    0.005181191745777913,
#    0.04224105753988223,
#    -0.0038355987834578767,
#    0.0020942435686471094,
#    -0.005478013551561278,
#    0.017162903451066195,
#    -0.006718069509644021,
#    -0.015527084774831454,
#    0.005870477990948313,
#    0.0013192085948453957,
#    0.005464821367823958,
#    -4.498707312893459e-05,
#    -0.01122646454143128,
#    0.012730362311615355,
#    -0.00924105625578643,
#    -0.012710574501670645,
#    -0.018244653204301093,
#    -0.004251149311554588,
#    -0.028442135796124222,
#    -0.027967220906870836,
#    0.00965660678388314,
#    -0.034985410501063186,
#    -0.005672596631872313,
#    -0.023534680698742535,
#    0.03258444982467655,
#    -0.006635619059777671,
#    -0.014775135889739418,
#    0.016213073672559426,
#    -0.013488907754237322,
#    0.00017273387524204984,
#    -0.006223366344784656,
#    0.02340275886136933,
#    -0.007070957863480363,
#    0.02506496283640125,
#    -0.013944033902223457,
#    0.001169973122262472,
#    -0.02282230836486246,
#    0.006579552511724694,
#    0.003690485926500524,
#    -0.009702778961302495,
#    0.028494904531073503,
#    -0.0014890566798949068,
#    -0.012677594507988612,
#    -0.023323607621590484,
#    -0.009478513700413123,
#    -0.01638456926717698,
#    0.0013150859792198245,
#    0.011912453439159254,
#    0.20199721236862928,
#    0.014128723543223405,
#    0.005886967987789329,
#    0.018811914311038257,
#    0.0256058377130187,
#    0.04429902330174361,
#    0.004851389480651247,
#    0.015645812565822263,
#    -0.02838936706117494,
#    0.0050657608365682625,
#    -0.009584050238989148,
#    -0.010487707840076564,
#    0.012473117057043952,
#    0.009353188420569848,
#    0.00884529353763443,
#    -0.03780851733175393,
#    -0.01400999482091006,
#    -0.03234699238004986,
#    -0.004280831492132924,
#    -0.021635019279083924,
#    -0.005197681742618929,
#    -0.012670997950458684,
#    0.0015096692923614941,
#    -0.013152509397241996,
#    -0.002504847144257643,
#    0.005464821367823958,
#    -0.015263242962730121,
#    0.020724766983111653,
#    0.02048730953848496,
#    0.026159905704696007,
#    -0.01298101193997937,
#    -0.022888268352226522,
#    0.017123325968531698,
#    0.002783530046648144,
#    0.00511523129275258,
#    0.0032666901671526707,
#    0.0015170898375060783,
#    -0.000894588265806301,
#    0.01763781834031958,
#    0.017400360895692888,
#    -0.01400999482091006,
#    0.012835898850191383,
#    0.002249250563407452,
#    0.02275634651485332,
#    -0.005055866931595907,
#    0.003951029692667527,
#    ...],
#   [0.012758627224051765,
#    0.008232850982422588,
#    0.007329005639361753,
#    0.015679749492618363,
#    0.004578172452229219,
#    0.033926943106962565,
#    -0.009411779690762807,
#    -0.01002089262390793,
#    -0.01502478940953689,
#    -0.005858619982760291,
#    -0.009988144526621596,
#    0.015077186551459553,
#    -0.014775904615218837,
#    -0.012594886737620088,
#    -0.0003659590616729459,
#    0.002510135417136064,
#    0.02179707879201487,
#    -0.008665125307808644,
#    0.012241208590779332,
#    -0.0004177418799124028,
#    -0.03314099249738099,
#    0.00463056959415188,
#    0.04343696895222962,
#    -0.0006340834388166848,
#    -0.0008948395115332975,
#    -0.005835696407792119,
#    -0.007826775693659171,
#    0.005278980150908345,
#    0.0006999888332655093,
#    0.003916662842822743,
#    0.014710408420646167,
#    -0.0008109227450677178,
#    0.008056011443340899,
#    -0.025399360180285577,
#    -0.0093135353989038,
#    -0.0060649326231351575,
#    -0.023146297047450463,
#    -0.021626790176242118,
#    0.006785388900789299,
#    -0.003572808519808185,
#    0.01433053123718277,
#    -0.02108972249833336,
#    -0.01688487723758122,
#    -0.005802948310505783,
#    0.009424878743412817,
#    -0.003919937373154591,
#    -0.007754729972761495,
#    -0.045192262496428624,
#    -0.013832761648546662,
#    0.004096776912236279,
#    0.026525891746703136,
#    0.025215971580540196,
#    0.0034450911266560003,
#    -0.009758908776939867,
#    0.004008357142695434,
#    0.008344194326931604,
#    -0.015889336197663764,
#    0.015876238076336376,
#    0.02737734041350262,
#    -0.027560729013248002,
#    -0.008959857252063044,
#    -0.006471007911898574,
#    -0.029342222525392272,
#    0.0009496924347895165,
#    -0.01616442095992708,
#    0.025268367791140237,
#    -0.02495398680224951,
#    0.010145335021066957,
#    0.00013928140784572965,
#    -0.011756537123470615,
#    0.02246513885906897,
#    0.023735760935959263,
#    -0.0036121061434195257,
#    0.00682468652440064,
#    0.018744963202980313,
#    -0.02797990428598405,
#    -0.012889618681874488,
#    0.02051335673115195,
#    0.009523123035271823,
#    0.0167800829537359,
#    -0.015247476098554926,
#    -0.022216254064750918,
#    -0.023866753325104604,
#    0.017566035425962714,
#    0.0059142916550148,
#    0.019661908064352467,
#    -0.00187646129461086,
#    0.01983219854277046,
#    -0.006785388900789299,
#    -0.03177867239532753,
#    0.004702614849388245,
#    0.02847767387462016,
#    0.0011846594856669346,
#    -0.00930043634625379,
#    -0.020225173847561246,
#    0.027901309970083988,
#    -0.006477557438223579,
#    0.016950373432153894,
#    -0.006857434621686975,
#    -0.005468918742640043,
#    -0.003477839223942336,
#    0.02680097650896645,
#    -0.010499014099230333,
#    -0.009496923998649183,
#    -0.03437231648499863,
#    -0.025700643047848915,
#    -0.010806845096134743,
#    -0.017828020204253395,
#    0.028084698569829373,
#    0.012883069621210792,
#    -0.01494619416231421,
#    0.010564509362480386,
#    0.02500638487549479,
#    -0.0023906050483054634,
#    -0.0136755711541013,
#    0.017015869626726562,
#    0.024678903902631437,
#    0.01679318293770853,
#    -0.020212075726233854,
#    -0.01735644872091731,
#    0.01305990822896986,
#    -0.0010078201794159018,
#    -0.00869787247377236,
#    -0.022910512237105038,
#    -0.001688160200875741,
#    -0.010466266001943999,
#    -0.02374886091993189,
#    -0.020356166236706587,
#    0.015404666593000287,
#    -0.005252781579947015,
#    0.011704140912870573,
#    0.011317713737420862,
#    0.024587209602758744,
#    -0.015928634286936416,
#    -0.018889055576098282,
#    0.007833325685645485,
#    -0.005639208289735416,
#    0.000958698149901726,
#    0.0021187966790192367,
#    0.002253063365665771,
#    0.0055638880385058915,
#    0.027193951813757236,
#    -0.0008457174820191217,
#    -0.010164984065703283,
#    0.03143809516378203,
#    0.00865857531582233,
#    -0.017199258226471947,
#    0.007866072851609202,
#    0.006680595082605287,
#    -0.008128057629899885,
#    -0.00311106155879026,
#    -0.02970899972488304,
#    0.01003399167655794,
#    0.004001807616370429,
#    0.006300718364803201,
#    0.014225737884660068,
#    -0.004165547637140797,
#    0.014134043584787377,
#    -0.035053474673380124,
#    -0.00932663445155381,
#    0.011278416579470832,
#    0.01675388484843588,
#    0.018509178392634888,
#    0.01616442095992708,
#    0.03693976060672447,
#    0.01486759891509153,
#    0.02228175025932359,
#    0.011396308984643543,
#    -0.014094745495514727,
#    0.007846424738295495,
#    -0.0063825881423577304,
#    0.03652058719663367,
#    -0.017487441110062653,
#    0.00873717056304501,
#    0.004047654766306775,
#    0.005852070456435286,
#    0.0009537859469503085,
#    -0.0032043933566595303,
#    -0.013426686359783245,
#    -0.012365650987938358,
#    -0.02669618222512113,
#    -0.02415493620869531,
#    -0.0047353629466745815,
#    0.015260575151204936,
#    -0.004506126731331542,
#    0.0056981544923217714,
#    0.0047091643757132505,
#    0.007270059436775397,
#    0.014160241690087397,
#    -0.025268367791140237,
#    0.0019959915470261335,
#    0.0017536562790330845,
#    0.005501666374265068,
#    0.014081646442864717,
#    -0.6505589802050101,
#    0.0005530321192221267,
#    -0.017906614520153456,
#    -0.0014507370776264458,
#    0.03204065717361822,
#    0.004689515796738235,
#    0.021325507308678784,
#    0.026394901220203035,
#    0.001423719990497481,
#    -0.015915536165609027,
#    0.0021482697803124145,
#    0.02120761490350607,
#    -0.003206030621825454,
#    0.0018977474879977817,
#    -0.016609792475317908,
#    -0.008475186716076947,
#    -0.016478801948817803,
#    -0.011075378935089123,
#    0.011062279882439113,
#    -0.009536222087921833,
#    -0.019006947981270995,
#    0.01495929321496422,
#    -0.006166451445326012,
#    0.024037043803522597,
#    0.007178365136902705,
#    0.0062188481215873625,
#    0.004948225113374452,
#    -0.02729874609760256,
#    -0.03227644570925412,
#    0.024403821003013363,
#    -0.005491842317608216,
#    0.010217381207625944,
#    0.003815143787801234,
#    -0.006670770560287124,
#    0.05072012790731634,
#    -0.02361786853078655,
#    -0.010970585582566422,
#    0.013000962026383504,
#    -0.008625827218535994,
#    0.020172777636961205,
#    0.01681938104300855,
#    0.0009505111255801421,
#    0.023172495152750484,
#    0.012778275337365471,
#    -0.007564791381029797,
#    -0.006628198406343937,
#    0.04663317505173691,
#    -0.006130428352046519,
#    -0.006968777500534682,
#    -0.02431212670314067,
#    0.04878144203808146,
#    -0.00024253998434645312,
#    -0.0023316586128884526,
#    -0.005033369886922138,
#    0.011016432732502766,
#    -0.037227945352960416,
#    0.019504717569907102,
#    -0.025202873459212804,
#    0.020133479547688553,
#    0.002824516406026789,
#    0.011573148523725232,
#    0.008547231971313312,
#    -0.011907178557252282,
#    -0.045087466349938064,
#    -0.021666086402869527,
#    0.03670397579637905,
#    -0.005858619982760291,
#    -0.014579416031500824,
#    -0.0006737904369271702,
#    -0.009234940151681118,
#    -0.0093135353989038,
#    0.03471289744183462,
#    -0.011599346629025252,
#    -0.01425193598996009,
#    0.020159677652988574,
#    -0.0011412683498948021,
#    0.02659138794127581,
#    -0.012653832940206444,
#    -0.018915253681398306,
#    0.00012833128027791034,
#    0.048807642006026726,
#    -0.014461523626328113,
#    -0.04755011805046382,
#    -0.015954832392236436,
#    0.028425277664020115,
#    -0.011140875129661795,
#    -0.026394901220203035,
#    0.0025215972046201507,
#    0.026460395552130464,
#    -0.019360627059434372,
#    0.013531479712305948,
#    0.03612761002919764,
#    0.025255269669812844,
#    -0.029054039641801567,
#    -0.008743720555031326,
#    0.011153974182311805,
#    0.016505000054117824,
#    0.04217944499666672,
#    0.0023234715885668685,
#    -0.051270293706552485,
#    0.000609113107768116,
#    -0.02991858642992844,
#    0.03002338071377376,
#    0.004466829107720202,
#    0.014697309367996157,
#    -0.005282254681240193,
#    -0.007021174642457343,
#    -0.004460279581395197,
#    0.01485449986244152,
#    -0.02418113431399533,
#    -0.0013926093912077244,
#    -0.023761959041259283,
#    -0.037778111152196564,
#    0.018482980287334867,
#    -0.015142682746032223,
#    -0.02304150276360514,
#    -0.0073879523076094186,
#    0.0136755711541013,
#    -0.0010896901898010856,
#    -0.03523686327312551,
#    0.0002083592509361024,
#    -0.025818535453021624,
#    -0.010603807451753036,
#    -0.0006881176712822783,
#    0.01740884493151735,
#    0.0034287173108434876,
#    0.02564824497460363,
#    0.009778557821576193,
#    -0.0033795951649139844,
#    0.001062673102672121,
#    0.011763087115456929,
#    0.005707979014639934,
#    0.00745344850218209,
#    0.011972674751824952,
#    -0.02186257498658754,
#    0.01886285747079826,
#    0.004293265030292982,
#    -0.010066739773844277,
#    0.00287691308228814,
#    -0.02122071302483346,
#    0.006890182253312001,
#    0.030128174997619085,
#    -0.01866636888708025,
#    -0.006641297458993947,
#    -0.012424597190524715,
#    -0.00747964660748211,
#    0.007846424738295495,
#    -0.01436982932645542,
#    -0.045611435906519435,
#    0.01972740425892514,
#    -0.018286491703616854,
#    -0.0017765798540012572,
#    -0.0017454692547115005,
#    0.02871346054761082,
#    -0.026905768930166534,
#    -0.007630287575602468,
#    0.009437977796062827,
#    -0.027717919507693367,
#    -0.027848911896838708,
#    -0.0029031116532494705,
#    0.034503308874143976,
#    0.007165265618591385,
#    -0.024613407708058765,
#    -0.003328835753818557,
#    0.0055638880385058915,
#    -0.008560331023963322,
#    -0.006500481013191752,
#    0.02871346054761082,
#    0.002469200295528145,
#    -0.02740353851880264,
#    0.012542489595697426,
#    -0.011350461834707197,
#    -0.008724071510395,
#    -0.010164984065703283,
#    0.00995539642933526,
#    0.032486030551654284,
#    -0.01423883693731008,
#    -0.008357293379581614,
#    -0.0002613701053614978,
#    -0.004329287657911165,
#    0.01852227837660752,
#    -0.018247193614344202,
#    -0.004326012661918007,
#    0.021535094013724186,
#    0.006415336239644066,
#    -0.007040823221432358,
#    0.046999952251227675,
#    0.011219470376884476,
#    0.0021941169302487603,
#    0.008894361057490374,
#    0.03426752406379855,
#    0.013963754037692004,
#    -0.010774096998848409,
#    0.022111459780905597,
#    0.01501169035688688,
#    -0.01431743218453276,
#    0.0040607538189567855,
#    -0.0032764388447265513,
#    0.01438292837910543,
#    0.025163575369940155,
#    0.01089199033534374,
#    0.023709562830659243,
#    0.00528552967723335,
#    -0.008953307260076728,
#    0.01372796829602396,
#    -0.03801389596254199,
#    0.0019747052372238844,
#    -0.028399079558720095,
#    0.020749143404142613,
#    0.012476993401124755,
#    0.005514765892576388,
#    -0.04115770585144924,
#    -0.005750551634244433,
#    -0.030416356018564548,
#    -0.01148145422385254,
#    0.007977416196118218,
#    0.007067021792393689,
#    0.019557115643152385,
#    0.010361471718098677,
#    -0.015116483709409583,
#    0.009424878743412817,
#    0.010079838826494287,
#    0.02433832480844069,
#    -0.002004178571347717,
#    -0.03416272791730799,
#    0.011429057081929879,
#    0.0011036081078647127,
#    -0.024377622897713343,
#    -0.020238273831533874,
#    -0.02004178524781586,
#    -0.022190055959450897,
#    0.019124840386443707,
#    0.01374106734867397,
#    0.01121292038489816,
#    -0.009189093001744773,
#    0.002387330285142961,
#    -0.0013254759314691295,
#    -0.03149049137438207,
#    -0.01427813502658273,
#    -0.0016267576348791893,
#    0.008900910118154068,
#    0.04920061917346275,
#    -0.003030828813571,
#    -0.030547348407709892,
#    -0.018915253681398306,
#    0.01628231336509979,
#    0.027901309970083988,
#    0.012228108606806702,
#    0.004221219309395305,
#    -0.016963471553481282,
#    -0.009948847368671566,
#    -0.020893233914615346,
#    -0.02858246815846548,
#    0.03400553928550787,
#    0.00018379823617901451,
#    0.01018463311033961,
#    -0.005354300402137868,
#    -0.008606178173899668,
#    0.029185032030946908,
#    0.006752640803502964,
#    0.025713741169176303,
#    0.004113150960879446,
#    0.005023545364603975,
#    0.004240867888370321,
#    0.012490093385097385,
#    0.006700244127241612,
#    -0.005115240130137977,
#    -0.009844053084826243,
#    0.013963754037692004,
#    -0.01672768674313586,
#    0.025373162074985557,
#    -0.023355883752495865,
#    0.0004261335623797272,
#    0.011258767534834506,
#    -0.0273511423082026,
#    -0.008920559162790394,
#    -0.030128174997619085,
#    -0.01550945994552299,
#    -0.0014703858894321161,
#    0.0035171368475536767,
#    -0.01793281262545348,
#    -0.01090508938799375,
#    0.02871346054761082,
#    0.03227644570925412,
#    -0.010066739773844277,
#    0.008612728165885984,
#    -0.01491999605701419,
#    0.014487721731628133,
#    -0.009457626840699153,
#    0.029001641568556287,
#    0.027036761319311875,
#    -0.004558523873254203,
#    -0.016491900070145196,
#    -0.023735760935959263,
#    -0.0142650350426101,
#    -0.019950090947943172,
#    0.011992322865138658,
#    -0.03618000623979768,
#    0.00986370212946257,
#    -0.00837694242421794,
#    0.00839004147686795,
#    -0.018247193614344202,
#    -0.001419626478336689,
#    0.0053772239771060415,
#    -0.006493931486866747,
#    -0.0038053194983137264,
#    -0.005786574261862616,
#    -0.008553781963299627,
#    -0.02363096851475918,
#    -0.024678903902631437,
#    -0.00927423824095377,
#    0.01148145422385254,
#    0.01430433313188275,
#    -0.02866106247436554,
#    0.0010291063728028235,
#    -0.01494619416231421,
#    -0.0029751571413164915,
#    -0.02118141679820605,
#    0.017173060121171927,
#    0.006199199076951037,
#    0.0028965618940938105,
#    -0.019714306137597747,
#    -0.0016021966783297651,
#    0.003995258090045424,
#    0.08362533559435191,
#    -0.013053359168306165,
#    -0.0042146697830703,
#    0.0205526548204246,
#    0.025071881070067463,
#    -0.0005440264041099172,
#    -0.02427282861386802,
#    -0.006346565514739547,
#    -0.002623116026811005,
#    0.016570496248690496,
#    -0.012765176284715461,
#    -0.0050530189315584634,
#    0.015142682746032223,
#    0.010256678365575976,
#    0.01607272666005439,
#    0.01082649414077107,
#    -0.006019085007537501,
#    -0.030180571208219126,
#    -0.013230197776065232,
#    -0.02610671833661233,
#    -0.0236571666200592,
#    0.000928406241402595,
#    0.004944950117381295,
#    0.012142964298920325,
#    0.009077749657235757,
#    0.024967086786222142,
#    0.023355883752495865,
#    0.01881045939755298,
#    0.027141555603157196,
#    -0.003389419687232147,
#    -0.005341201349487858,
#    0.006356389571396399,
#    0.0022907237241111883,
#    -0.005681780443678604,
#    -0.006936029868909657,
#    -0.004607645553522397,
#    -0.006680595082605287,
#    0.003053752388539173,
#    0.01425193598996009,
#    -0.009117047746508407,
#    0.00015125489890183103,
#    0.0015391567307519623,
#    0.005691604965996766,
#    -0.044065730930011066,
#    0.002293998487273691,
#    0.022569931280269052,
#    0.000998814522511356,
#    0.041943656461030814,
#    0.00774818044643649,
#    -0.0015997405477502244,
#    0.01556185708744565,
#    0.01625611525979977,
#    0.009025353446635714,
#    -0.002791768308740454,
#    -0.025923329736866948,
#    0.011357011826693512,
#    -0.0006836148428300054,
#    0.00014859412472846583,
#    0.008868162952190353,
#    -0.03869505415092348,
#    -0.009090848709885767,
#    -0.03460810129534406,
#    -0.01307300728161987,
#    -0.012201910501506682,
#    0.002144995017149912,
#    -0.026342503146957755,
#    0.011383209931993533,
#    0.015299872309154966,
#    -0.023185595136723112,
#    0.009785106882239887,
#    0.011442156134579889,
#    -0.023932249519677276,
#    -0.020709845314869964,
#    -0.0017700302112609247,
#    0.02533386398571291,
#    -0.005089041559176647,
#    0.010158434073716967,
#    -0.0038642657009000823,
#    -0.002670600674743929,
#    0.019530915675207126,
#    0.0068967322452983156,
#    0.001113432513767548,
#    -0.024914690575622102,
#    -0.0010004519040926073,
#    -0.0020336516726408953,
#    0.007283158489425407,
#    0.028241889064274734,
#    -0.018129301209171493,
#    0.011448706126566205,
#    0.01615132097595445,
#    0.03232884191985416,
#    0.003661228056518374,
#    0.015050987514836913,
#    0.0035990068579388602,
#    0.018954551770670954,
#    -0.0014368191595628187,
#    0.0077612794990865,
#    0.009189093001744773,
#    0.005357575398131026,
#    -0.02052645671512458,
#    0.030232967418819166,
#    -0.003296087656532222,
#    0.006500481013191752,
#    -0.016059626676081757,
#    0.01873186508165292,
#    -0.01980600043747044,
#    -0.01916413847571636,
#    0.03838067316203276,
#    -0.004453730055070192,
#    0.008213201937786262,
#    0.006474282442230421,
#    -0.004601096027197392,
#    -0.0023578571838497827,
#    -0.011435607073916193,
#    -0.027560729013248002,
#    0.022635427474841725,
#    0.0038773649863807474,
#    0.006667496029955277,
#    -0.019976289053243192,
#    0.009627916387794524,
#    0.027744119475638627,
#    -0.013832761648546662,
#    0.01970120615362512,
#    -0.014134043584787377,
#    -0.007335555631348068,
#    -0.010767547006862093,
#    0.004794309614922247,
#    0.0008825590332585854,
#    0.0015014964887218728,
#    0.0040574792886249374,
#    0.01680628105903592,
#    0.01798521069869876,
#    -0.030678340796855233,
#    -0.023945349503649904,
#    -0.01435673027380541,
#    -0.011206370392911846,
#    0.014134043584787377,
#    0.010079838826494287,
#    0.009516573043285508,
#    -0.01801140880399878,
#    -0.0017634805685205921,
#    -0.017605333515235362,
#    -0.03235503816250894,
#    -0.008566881015949638,
#    0.009778557821576193,
#    -0.03266941915139966,
#    -0.005937215229982973,
#    -0.03002338071377376,
#    -0.0035400604225218494,
#    0.04013596670623176,
#    -0.0030701264371823405,
#    -0.000575137003399674,
#    -0.01272587912676543,
#    0.015850039971036355,
#    -0.010715150796262052,
#    -0.016295413349072422,
#    -0.010911638448657446,
#    0.003821693314126239,
#    0.009097398701872081,
#    0.018941451786698326,
#    0.010151885013053273,
#    0.0034352668371684927,
#    0.015928634286936416,
#    0.01121292038489816,
#    0.012463894348474745,
#    0.0006991701424748837,
#    -0.002187567403923755,
#    -0.006071482149460163,
#    -0.028163292885729434,
#    0.0076892337781888235,
#    0.01372796829602396,
#    0.012889618681874488,
#    0.000380900357776771,
#    0.014710408420646167,
#    0.0032584275309174597,
#    0.01809000311989884,
#    0.020565752941751992,
#    -0.01305990822896986,
#    -0.008291797185008944,
#    -0.017867316430880808,
#    -0.006271244797848713,
#    -0.008245950035072598,
#    -0.02803230049658409,
#    0.011298065624107156,
#    0.032486030551654284,
#    0.007034273695107353,
#    0.036965960574669735,
#    0.01881045939755298,
#    -0.005655582338378583,
#    -0.011298065624107156,
#    0.010590708399103026,
#    -0.0015538932813985511,
#    0.017801820236308136,
#    -0.0023087350379202795,
#    -0.0037954949759955634,
#    -0.0010151884547391964,
#    0.006042009048166984,
#    -0.042991595574193554,
#    -0.03096652368044594,
#    0.004306364082942992,
#    0.024547911513486096,
#    -0.005590086143805913,
#    0.004872904862144928,
#    -0.0029162107058994806,
#    0.025726841153148935,
#    0.03764711876305123,
#    -0.013767265453973991,
#    -0.010833043201434764,
#    -0.0161906190652271,
#    0.0028589017684790483,
#    -0.01093128749329377,
#    -0.016635992443263168,
#    -0.01860087269250758,
#    -0.04034555527392241,
#    0.00493840059105629,
#    0.00117401633076581,
#    -0.01799830882002615,
#    0.0385902617297234,
#    -0.012201910501506682,
#    -0.007558241854704792,
#    -0.028320483380174795,
#    -0.021102820619660748,
#    -0.0030095425037687507,
#    -0.010996783687866442,
#    0.02991858642992844,
#    -0.023932249519677276,
#    0.005452544693996875,
#    -0.0032322291927867845,
#    0.003962509992759089,
#    -0.008986055357363064,
#    -0.013754166401323981,
#    0.03460810129534406,
#    -0.004551974346929198,
#    0.011795835212743265,
#    -0.011180172287611825,
#    -0.017015869626726562,
#    0.020696745330897333,
#    -0.025229071564512824,
#    -0.02923742824154695,
#    0.015365368503727637,
#    0.03793529978399669,
#    -0.00839004147686795,
#    -0.017592233531262734,
#    0.01860087269250758,
#    0.010459716009957683,
#    0.02923742824154695,
#    0.00040771278675999533,
#    0.014553217926200804,
#    -0.01875806318695294,
#    0.026290106936357714,
#    -0.027875110002138728,
#    0.007348654683998078,
#    -0.021338607292651413,
#    0.014605615068123464,
#    0.026263908831057694,
#    0.011998872857124972,
#    -0.012195360509520366,
#    -0.0004916295532255751,
#    -0.020814637736070046,
#    0.005966688331276151,
#    0.001094602450960167,
#    0.020408562447306627,
#    -0.03806629217314203,
#    0.0007511576188600811,
#    0.014697309367996157,
#    0.022687825548087005,
#    -0.0021106096546976527,
#    0.00448320315636337,
#    0.00463056959415188,
#    0.02803230049658409,
#    -0.015823841865736335,
#    -0.015286773256504956,
#    0.0050399194132471434,
#    0.016963471553481282,
#    0.009516573043285508,
#    0.004633844124483727,
#    -0.018469880303362236,
#    -0.02059195290969725,
#    -0.0045716229259042136,
#    0.0058979176063716325,
#    0.015050987514836913,
#    0.005783299731530768,
#    0.0004359579682825623,
#    -0.02112901872496077,
#    0.004712439371706408,
#    -0.03576083282970687,
#    -0.005842245934117124,
#    -0.0002202303983674176,
#    -0.008324545282295278,
#    0.0007126786860393662,
#    -0.010060190713180582,
#    0.00039829772625247297,
#    -0.009667214477067176,
#    0.029394618735992313,
#    0.012732428187429125,
#    0.00837694242421794,
#    0.0073879523076094186,
#    0.02740353851880264,
#    -0.04718334085097306,
#    0.01545706280360033,
#    -0.02006798335311588,
#    0.017788722114980747,
#    -0.041498286808285226,
#    0.015823841865736335,
#    0.008049462382677204,
#    -0.016112022886681798,
#    0.004018181665013597,
#    -0.015784543776463683,
#    -0.025805435469048996,
#    -0.04899103060577211,
#    -0.01689797535890861,
#    -0.0037889454496705583,
#    -0.0007446079761197485,
#    0.007964317143468208,
#    -0.008049462382677204,
#    -0.018535376497934908,
#    0.01980600043747044,
#    -8.673107426601917e-06,
#    -0.01609892476535441,
#    0.012968213929097168,
#    -0.0012714416407958724,
#    -0.01498549225158686,
#    -0.006922930350598337,
#    -0.008141156682549895,
#    0.022530635053641643,
#    0.007211112768527731,
#    -0.010649654601689382,
#    -0.0007499295535703108,
#    -0.03167387997412745,
#    -0.006657671507637114,
#    0.002554345301906486,
#    -0.011736889010156909,
#    -0.006431710288287234,
#    -0.013387388270510595,
#    -0.005583536617480908,
#    -0.010158434073716967,
#    -0.006212298595262357,
#    0.026604487925248436,
#    0.003170007994207271,
#    -0.004905652493769954,
#    0.011095027979725449,
#    0.0180376069092988,
#    0.0008604540908733744,
#    0.0015170517883667512,
#    0.022609229369541704,
#    -0.011016432732502766,
#    -0.035027278430725346,
#    -0.007630287575602468,
#    -0.013282594917987894,
#    -0.03620620620774294,
#    -0.005485292791283211,
#    0.03908803131835951,
#    0.011959574767852322,
#    -0.023224893225995764,
#    0.0013623174245009295,
#    0.009333184443540124,
#    -0.05221343667322466,
#    0.0074141508785707496,
#    0.015339170398427616,
#    0.014107844548164737,
#    0.04320118041659372,
#    -0.008468636724090631,
#    -0.0054066975440605295,
#    0.023185595136723112,
#    0.00954277207990815,
#    0.019661908064352467,
#    -0.011612446612997882,
#    0.0010643104842533722,
#    0.017487441110062653,
#    -0.009503473990635497,
#    0.029342222525392272,
#    -0.01928203088088907,
#    -0.0311237141748913,
#    -0.00208768607972948,
#    0.009248039204331128,
#    0.024639607676004024,
#    -0.007925019985518178,
#    0.007663035672888803,
#    -0.005924116177332963,
#    0.00373327377741605,
#    -0.007879172835581831,
#    0.0023251090865634475,
#    0.001479391546336662,
#    0.02052645671512458,
#    0.01867946887105288,
#    -0.0434631651948844,
#    -0.009280787301617464,
#    0.005806223306498941,
#    0.0028146918837086265,
#    0.008422789574154285,
#    0.0025134101802985667,
#    0.00015770215436162964,
#    -0.022255552154023566,
#    -0.009241490143667434,
#    -0.03232884191985416,
#    -0.01554875803479564,
#    -0.004781210096610927,
#    -0.008029813338040879,
#    -0.016518098175445216,
#    0.02661758604657583,
#    -0.0229891065530051,
#    0.018561574603234928,
#    0.005475468268965048,
#    -0.011527301373788885,
#    0.0019681557108988793,
#    -0.0038708154600557423,
#    -0.04152448305094001,
#    -0.004840156764858593,
#    -0.008861612960204037,
#    -0.03345537348627172,
#    -0.02923742824154695,
#    -0.023198693258050504,
#    -0.0021973919262419177,
#    -0.010394219815385013,
#    0.000495723065386367,
#    0.00865857531582233,
#    0.015981032360181696,
#    -0.007820225701672855,
#    0.00966066448508086,
#    0.022818817937232345,
#    -0.023709562830659243,
#    -0.007040823221432358,
#    -0.0204740586418793,
#    -0.013014061079033514,
#    0.0019337703484466199,
#    -0.007073571318718694,
#    -0.0025379712532633183,
#    -0.014042349284914686,
#    0.008285248124345248,
#    -0.0021351704948317494,
#    -0.011579698515711546,
#    0.0038053194983137264,
#    0.01945232135930706,
#    -0.0018240645019341817,
#    -0.011710689973534269,
#    -0.0019468695175119575,
#    0.20424282055544737,
#    0.010479365054594009,
#    -0.017605333515235362,
#    0.011717239965520583,
#    -0.006994976071496012,
#    0.030259165524119187,
#    0.003821693314126239,
#    0.01032872362081234,
#    -0.00390028856134892,
#    0.017028967748053955,
#    -0.019976289053243192,
#    -0.015732145703218403,
#    0.011998872857124972,
#    0.007106319416005029,
#    -0.002973519876150568,
#    -0.04883384197397198,
#    -0.013858959753846684,
#    -0.015679749492618363,
#    -0.024678903902631437,
#    -0.0036153809065820283,
#    0.008016714285390868,
#    -0.018378186003489547,
#    -0.0371755454170699,
#    -0.01370176925940132,
#    0.026656884135848477,
#    -0.008914010102126698,
#    -0.023958447624977296,
#    -0.0067264422325416335,
#    -0.003949410474447769,
#    0.02305460274757777,
#    -0.003263339792076541,
#    -0.02479679630780415,
#    -0.008514483874026977,
#    0.013171251573478877,
#    -0.001025831609640321,
#    -0.004005082146702277,
#    0.04375134994112034,
#    -0.018836657502853002,
#    0.008599629113235974,
#    0.03523686327312551,
#    -0.01797211071472613,
#    0.021574392102996838,
#    0.021639888297569507,
#    -0.011075378935089123,
#    -0.00777437901739782,
#    0.023329685647195845,
#    ...]],
#  'metadatas': [{'bathrooms': 3,
#    'bedrooms': 4,
#    'house size': 280,
#    'neighborhood': 'Central Park',
#    'price': 3500000},
#   {'bathrooms': 2,
#    'bedrooms': 3,
#    'house size': 200,
#    'neighborhood': 'Ocean View',
#    'price': 1800000}],
#  'documents': ['Modern Luxury in Central Park: Indulge in the epitome of modern luxury with this stunning 4-bedroom, 3-bathroom home in Central Park. Boasting high-end finishes, a gourmet kitchen, and panoramic views of the city skyline, this property offers a sophisticated urban lifestyle. Neighborhood: Central Park is a vibrant neighborhood known for its upscale dining, shopping, and cultural attractions. Enjoy easy access to the park for leisurely strolls and outdoor activities.',
#   'Seaside Retreat in Ocean View: Escape to this charming seaside retreat in Ocean View. With 3 bedrooms, 2 bathrooms, and a spacious deck overlooking the ocean, this home offers a perfect blend of coastal living and modern comfort. Neighborhood: Ocean View is a picturesque coastal community with sandy beaches, seafood restaurants, and a laid-back atmosphere. Experience the tranquility of seaside living in this charming neighborhood.']}

# %% [markdown]
# # STEP 3 - SEMANTIC SEARCH FONCTIONALITY

# %%
# load property database to pandas
df = pd.read_json('data/property_listings.json')
df
# Out:
#                           listings_headline listings_neighborhood  \
# 0             Modern Luxury in Central Park          Central Park
# 1             Seaside Retreat in Ocean View            Ocean View
# 2    Historic Elegance in Heritage District     Heritage District
# 3    Contemporary Living in Skyline Heights       Skyline Heights
# 4            Tranquil Haven in Willow Creek          Willow Creek
# 5           Urban Chic in Downtown District     Downtown District
# 6               Rustic Charm in Maple Grove           Maple Grove
# 7       Luxurious Retreat in Hillside Manor        Hillside Manor
# 8         Coastal Living in Seaview Heights       Seaview Heights
# 9         Elegant Oasis in Rosewood Estates      Rosewood Estates
# 10            Serenity in Pinecrest Meadows     Pinecrest Meadows
# 11           Modern Elegance in Silver Lake           Silver Lake
# 12  Charming Cottage in Willowbrook Village   Willowbrook Village
# 13         Luxury Living in Diamond Heights       Diamond Heights
# 14         Tranquil Retreat in Cedar Valley          Cedar Valley
# 15               Urban Oasis in City Center           City Center
#
#     listings_price  listings_bedrooms  listings_bathrooms  \
# 0          3500000                  4                   3
# 1          1800000                  3                   2
# 2          1200000                  5                   4
# 3          2800000                  6                   5
# 4          1500000                  4                   3
# 5          2000000                  3                   2
# 6          1300000                  4                   3
# 7          3000000                  5                   4
# 8          2200000                  3                   2
# 9          2600000                  4                   3
# 10         1700000                  5                   4
# 11         1900000                  3                   2
# 12         1400000                  2                   1
# 13         2700000                  4                   3
# 14         1600000                  3                   2
# 15         2500000                  4                   3
#
#     listings_house_size                               listings_description  \
# 0                   280  Indulge in the epitome of modern luxury with t...
# 1                   200  Escape to this charming seaside retreat in Oce...
# 2                   320  Step back in time with this historic 5-bedroom...
# 3                   400  Experience contemporary living at its finest i...
# 4                   250  Find peace and serenity in this tranquil 4-bed...
# 5                   180  Embrace urban chic living in this stylish 3-be...
# 6                   220  Discover the rustic charm of this 4-bedroom, 3...
# 7                   350  Escape to a luxurious retreat in the prestigio...
# 8                   190  Experience the beauty of coastal living in thi...
# 9                   240  Discover an elegant oasis in the prestigious R...
# 10                  260  Find serenity in this 5-bedroom, 4-bathroom ho...
# 11                  210  Experience modern elegance in this 3-bedroom, ...
# 12                  150  Escape to this charming cottage in the heart o...
# 13                  230  Indulge in luxury living in this 4-bedroom, 3-...
# 14                  170  Find peace and tranquility in this 3-bedroom, ...
# 15                  260  Discover an urban oasis in the heart of the Ci...
#
#                     listings_neighborhood_description  \
# 0   Central Park is a vibrant neighborhood known f...
# 1   Ocean View is a picturesque coastal community ...
# 2   The Heritage District is a historic neighborho...
# 3   Skyline Heights offers a vibrant urban lifesty...
# 4   Willow Creek is a quiet residential neighborho...
# 5   The Downtown District is a bustling urban cent...
# 6   Maple Grove is a quaint neighborhood with tree...
# 7   Hillside Manor is an exclusive neighborhood kn...
# 8   Seaview Heights is a coastal community with sa...
# 9   Rosewood Estates is an upscale neighborhood kn...
# 10  Pinecrest Meadows is a nature lover's paradise...
# 11  Silver Lake is a trendy neighborhood known for...
# 12  Willowbrook Village is a quaint village with h...
# 13  Diamond Heights is an exclusive neighborhood k...
# 14  Cedar Valley is a peaceful neighborhood with h...
# 15  City Center is a vibrant urban hub with shoppi...
#
#                                      full_description
# 0   Modern Luxury in Central Park: Indulge in the ...
# 1   Seaside Retreat in Ocean View: Escape to this ...
# 2   Historic Elegance in Heritage District: Step b...
# 3   Contemporary Living in Skyline Heights: Experi...
# 4   Tranquil Haven in Willow Creek: Find peace and...
# 5   Urban Chic in Downtown District: Embrace urban...
# 6   Rustic Charm in Maple Grove: Discover the rust...
# 7   Luxurious Retreat in Hillside Manor: Escape to...
# 8   Coastal Living in Seaview Heights: Experience ...
# 9   Elegant Oasis in Rosewood Estates: Discover an...
# 10  Serenity in Pinecrest Meadows: Find serenity i...
# 11  Modern Elegance in Silver Lake: Experience mod...
# 12  Charming Cottage in Willowbrook Village: Escap...
# 13  Luxury Living in Diamond Heights: Indulge in l...
# 14  Tranquil Retreat in Cedar Valley: Find peace a...
# 15  Urban Oasis in City Center: Discover an urban ...

# %% [markdown]
# ### RUBRIC #3 Semantic Search of Listings Based on Buyer Preferences

# %%
def query_db(query: str,
             metadata: Optional[dict] = None,
             search_string: Optional[str] = ' ',
             n_results: int = 10
             ):
    """
    text query the database and return the n closest vector entries
    inputs:
    - query: the query string
    - metadata: the metadata to filter the results
        - Provide metadata as a dictionary with metadata keys and values as lists of values to filter for
        - targets can be composed with the following operators:
        e.g {'house size': {"$gte": 200}
            $eq - equal to (string, int, float)
            $ne - not equal to (string, int, float)
            $gt - greater than (int, float)
            $gte - greater than or equal to (int, float)
            $lt - less than (int, float)
            $lte - less than or equal to (int, float)
    - search_string: the string or keyword to search in the listing description
    - n_results: the number of results to return (int - default = 10)
    returns:
    - the n closest results as a list of dictionaries.
    The results are ordered by the distance to the query in ascending order (lowest in best match)
    Returns the ids, description, metadata and distance of the corresponding vector entries
    """
    # compute the embeddings of the query for semantic search
    query_embeddings = embeddings_model.embed_documents([query])
    # defines the keywords for the search function
    kwargs  = {'query_embeddings':query_embeddings, 'n_results':n_results}
    if metadata:
        kwargs['where'] = metadata
    if search_string:
        kwargs['where_document'] = {"$contains":search_string}
    # serach the vector db using the defined arguments & return results
    results = collection.query(**kwargs)

    return results

# %%
query = "nice house with a view on the sea"
query_db(query=query, n_results=3)
# Out:
# {'ids': [['8', '1', '11']],
#  'distances': [[0.2822312941790316, 0.2836603463282615, 0.4023989250458718]],
#  'metadatas': [[{'bathrooms': 2,
#     'bedrooms': 3,
#     'house size': 190,
#     'neighborhood': 'Seaview Heights',
#     'price': 2200000},
#    {'bathrooms': 2,
#     'bedrooms': 3,
#     'house size': 200,
#     'neighborhood': 'Ocean View',
#     'price': 1800000},
#    {'bathrooms': 2,
#     'bedrooms': 3,
#     'house size': 210,
#     'neighborhood': 'Silver Lake',
#     'price': 1900000}]],
#  'embeddings': None,
#  'documents': [['Coastal Living in Seaview Heights: Experience the beauty of coastal living in this 3-bedroom, 2-bathroom home in Seaview Heights. With ocean views, a sun-drenched deck, and beach access just steps away, this property offers a perfect seaside retreat. Neighborhood: Seaview Heights is a coastal community with sandy beaches, seaside cafes, and water sports activities. Enjoy the laid-back lifestyle and stunning ocean views in this charming neighborhood.',
#    'Seaside Retreat in Ocean View: Escape to this charming seaside retreat in Ocean View. With 3 bedrooms, 2 bathrooms, and a spacious deck overlooking the ocean, this home offers a perfect blend of coastal living and modern comfort. Neighborhood: Ocean View is a picturesque coastal community with sandy beaches, seafood restaurants, and a laid-back atmosphere. Experience the tranquility of seaside living in this charming neighborhood.',
#    'Modern Elegance in Silver Lake: Experience modern elegance in this 3-bedroom, 2-bathroom home in Silver Lake. With sleek design, high ceilings, and a rooftop deck with panoramic views of the lake, this property offers a perfect blend of style and sophistication. Neighborhood: Silver Lake is a trendy neighborhood known for its hip cafes, art galleries, and scenic lake views. Embrace the vibrant energy and creative spirit of this eclectic community.']]}

# %%
query_db(query=query, n_results=3, metadata={'house size': {"$gte": 200}})
# Out:
# {'ids': [['1', '11', '3']],
#  'distances': [[0.2836603463282615, 0.4023989250458718, 0.40659283973841437]],
#  'metadatas': [[{'bathrooms': 2,
#     'bedrooms': 3,
#     'house size': 200,
#     'neighborhood': 'Ocean View',
#     'price': 1800000},
#    {'bathrooms': 2,
#     'bedrooms': 3,
#     'house size': 210,
#     'neighborhood': 'Silver Lake',
#     'price': 1900000},
#    {'bathrooms': 5,
#     'bedrooms': 6,
#     'house size': 400,
#     'neighborhood': 'Skyline Heights',
#     'price': 2800000}]],
#  'embeddings': None,
#  'documents': [['Seaside Retreat in Ocean View: Escape to this charming seaside retreat in Ocean View. With 3 bedrooms, 2 bathrooms, and a spacious deck overlooking the ocean, this home offers a perfect blend of coastal living and modern comfort. Neighborhood: Ocean View is a picturesque coastal community with sandy beaches, seafood restaurants, and a laid-back atmosphere. Experience the tranquility of seaside living in this charming neighborhood.',
#    'Modern Elegance in Silver Lake: Experience modern elegance in this 3-bedroom, 2-bathroom home in Silver Lake. With sleek design, high ceilings, and a rooftop deck with panoramic views of the lake, this property offers a perfect blend of style and sophistication. Neighborhood: Silver Lake is a trendy neighborhood known for its hip cafes, art galleries, and scenic lake views. Embrace the vibrant energy and creative spirit of this eclectic community.',
#    'Contemporary Living in Skyline Heights: Experience contemporary living at its finest in this 6-bedroom, 5-bathroom home in Skyline Heights. With sleek design, high ceilings, and a rooftop terrace with city views, this property is perfect for modern urban dwellers. Neighborhood: Skyline Heights offers a vibrant urban lifestyle with trendy cafes, art galleries, and easy access to public transportation. Enjoy the bustling energy of the city from the comfort of your stylish home.']]}

# %%
query_db(query=query, n_results=3, metadata={'house size': {"$gte": 200}}, search_string='sea')
# Out:
# {'ids': [['1']],
#  'distances': [[0.2836603463282615]],
#  'metadatas': [[{'bathrooms': 2,
#     'bedrooms': 3,
#     'house size': 200,
#     'neighborhood': 'Ocean View',
#     'price': 1800000}]],
#  'embeddings': None,
#  'documents': [['Seaside Retreat in Ocean View: Escape to this charming seaside retreat in Ocean View. With 3 bedrooms, 2 bathrooms, and a spacious deck overlooking the ocean, this home offers a perfect blend of coastal living and modern comfort. Neighborhood: Ocean View is a picturesque coastal community with sandy beaches, seafood restaurants, and a laid-back atmosphere. Experience the tranquility of seaside living in this charming neighborhood.']]}

# %% [markdown]
# # STEP 4 - BUILD USER PREFERENCE INTERFACE

# %% [markdown]
# - prepare schema and output parser to extract key preference characteristics from customer message

# %%
# Keep this cell formating as it influences the llm output with int instead of 'int' !
price_schema = ResponseSchema(name="price",
                              description="Did the customer indicated a maximum price for the property? \
                                Provide the price value if yes, -1 if not or unknown.")
bathrooms_schema = ResponseSchema(name="bathrooms",
                                  description="Did the customer indicated the number of bathrooms for the property? \
                                    Provide the number value if yes, -1 if not or unknown.")
bedrooms_schema = ResponseSchema(name="bedrooms",
                                 description="Did the customer indicated the number of bedrooms for the property? \
                                    Provide the number value if yes, -1 if not or unknown.")
size_schema = ResponseSchema(name="house size",
                             description="Did the customer indicated the minimum size of the property? \
                                Provide the number value if yes, -1 if not or unknown.")

response_schemas = [price_schema, 
                    bathrooms_schema,
                    bedrooms_schema,
                    size_schema]

output_parser = StructuredOutputParser.from_response_schemas(response_schemas)
format_user_preferences = output_parser.get_format_instructions()
print(format_user_preferences)
# Out:
# The output should be a markdown code snippet formatted in the following schema, including the leading and trailing "```json" and "```":
#
# ```json
# {
# 	"price": string  // Did the customer indicated a maximum price for the property?                                 Provide the price value if yes, -1 if not or unknown.
# 	"bathrooms": string  // Did the customer indicated the number of bathrooms for the property?                                     Provide the number value if yes, -1 if not or unknown.
# 	"bedrooms": string  // Did the customer indicated the number of bedrooms for the property?                                     Provide the number value if yes, -1 if not or unknown.
# 	"house size": string  // Did the customer indicated the minimum size of the property?                                 Provide the number value if yes, -1 if not or unknown.
# }
# ```

# %%
def build_where_expression(dict_of_metadata):
    """
    Builds a where_document for metadata search, format expected by vectorDB
    """
    # eliminate all metadata keys with no value identified (-1)
    dict_of_metadata = {k:v for k,v in dict_of_metadata.items() if v != -1}
    # build metadata search expression using Where format expected by vectorDB
    expression = {}
    try:
        max_price = dict_of_metadata['price']
        # use less than or equal operator for price
        dict_of_metadata['price'] = {"$lte": max_price}
    except:
        pass
    if len(dict_of_metadata) >1:
        # combine all metadata search expressions into a single Where expression
        expression = {"$and": [{k:v} for k,v in dict_of_metadata.items()]}
    return expression

# %%
# Prompt template for finding user preferences.
# It uses the schema defined above
find_preferences_template = """\
For the following customer input, extract the following information:

price: Did the customer indicated a maximum price for the property? \
Provide the price value if yes, -1 if not or unknown.

bathrooms: Did the customer indicated the number of bathrooms for the property? \
Provide the number value if yes, -1 if not or unknown.

bedrooms: Did the customer indicated the number of bedrooms for the property? \
Provide the number value if yes, -1 if not or unknown.

House size: Did the customer indicated the minimum size of the property? \
Provide the number value if yes, -1 if not or unknown.

customer input: {customer_input}

{format_user_preferences}
"""

# %%
def find_best_matches(customer_input, top_k=3):
    '''   
    takes in the customer text input indicating his preferences, find the best property matches and extract customer preference characteristics as metadata
    returns :
    - the top k (default = 3) best property matches using query_db function
    - the key characteristics indicated by the customer for the preperty metadata

    input:
    - customer_input: str
    outputs:
    - listings_results: dictionary with property matches from query_db function
    - output_dict: dictionary with key, value pairs representing the metadata and their extracted values
    '''
    pref_prompt = ChatPromptTemplate.from_template(template=find_preferences_template)
    messages = pref_prompt.format_messages(customer_input=customer_input, 
                                  format_user_preferences=format_user_preferences)

    # Use LLM to extratc the preferences from the conversation
    response = chat_llm(messages)
    output_dict = output_parser.parse(response.content)
    print(f'Extracted desired preferencies: {output_dict}')

    # Query the vectordb with the customer input and the key preference characteristics on metadata
    listings_results = query_db(query=customer_input, 
                                n_results=top_k, 
                                metadata=build_where_expression(output_dict)
                                )
    return listings_results, output_dict

# %%
def display_matches(matches, threshold=0.52, df=df):
    '''   
    takes in the list of property matches from query_db function
    displays the property characterics from the df dataframe
    filter out the matches with distance above a threshold (default is 0.52)
    inputs:
    - property matches from query_db function
    - threshold: float between 0 and 1. lower is more restrictive
    - df: dataframe with the properties details (default is database)
    outputs:
    - matches_df: input dataframe filtered to property matches below threshold
    '''
    idx = matches['ids'][0]
    idx = [int(i) for i in idx]
    if len(idx)>0:
        idx = [id for i,id in enumerate(idx) if matches['distances'][0][i]<=threshold]
        
    if len(idx)>0:
        matches_df = df.loc[idx]
        
        for i, id in enumerate(idx):
                print(YELLOW + f"Distance {str(round(matches['distances'][0][i],3))} : {matches_df.loc[id,'listings_headline']}" + ENDC)
                for key in list(listings_description_model.model_fields.keys())[1:]:
                    print(f'- {key.split("listings_")[1].replace("_"," "):<25} : {matches_df.loc[id,key]}')
                print('-------------------------------------------------')
    else:
        matches_df = pd.DataFrame()
        print(RED + "No match found with these characteristics" + ENDC)

    return matches_df

# %% [markdown]
# ### RUBRIC #3 Semantic Search of Listings Based on Buyer Preferences

# %%
customer_input = "i am looking for a property with a view on the sea with 3 bedrooms, 3 bathrooms and maximum price of 2000000 euros"

extrated_properties, extracted_prefs = find_best_matches(customer_input)

matches_df = display_matches(extrated_properties)
# Out:
# Extracted desired preferencies: {'price': 2000000, 'bathrooms': 3, 'bedrooms': 3, 'house size': -1}
# No match found with these characteristics

# %%
customer_input = "i am looking for a property with a view on the sea with 3 bedrooms, 2 bathrooms and maximum price of 2000000 euros"

extrated_properties, extracted_prefs = find_best_matches(customer_input)

matches_df = display_matches(extrated_properties)
# Out:
# Extracted desired preferencies: {'price': 2000000, 'bathrooms': 2, 'bedrooms': 3, 'house size': -1}
# Distance 0.439 : Seaside Retreat in Ocean View
# - neighborhood              : Ocean View
# - price                     : 1800000
# - bedrooms                  : 3
# - bathrooms                 : 2
# - house size                : 200
# - description               : Escape to this charming seaside retreat in Ocean View. With 3 bedrooms, 2 bathrooms, and a spacious deck overlooking the ocean, this home offers a perfect blend of coastal living and modern comfort.
# - neighborhood description  : Ocean View is a picturesque coastal community with sandy beaches, seafood restaurants, and a laid-back atmosphere. Experience the tranquility of seaside living in this charming neighborhood.
# -------------------------------------------------
# Distance 0.51 : Modern Elegance in Silver Lake
# - neighborhood              : Silver Lake
# - price                     : 1900000
# - bedrooms                  : 3
# - bathrooms                 : 2
# - house size                : 210
# - description               : Experience modern elegance in this 3-bedroom, 2-bathroom home in Silver Lake. With sleek design, high ceilings, and a rooftop deck with panoramic views of the lake, this property offers a perfect blend of style and sophistication.
# - neighborhood description  : Silver Lake is a trendy neighborhood known for its hip cafes, art galleries, and scenic lake views. Embrace the vibrant energy and creative spirit of this eclectic community.
# -------------------------------------------------

# %% [markdown]
# # STEP 5 - AUGMENT AND PERSONALIZE LISTING DESCRIPTION TO CUSTOMER PREFERENCES

# %% [markdown]
# ### RUBRIC #4 Logic for Searching and Augmenting Listing Descriptions

# %% [markdown]
# - summarize the preferences of the customer

# %%
summarize_preferences_prompt_template = ''' 
Based on the customer input and extracted perference characterisctics below, summarize the user preferencies describing the ideal property the customer is looking for.
- Be concise.
- Only use what is provided to you. Do not alter or modify preferencies.
- Do not add preferencies not mentionned by the customer as this could flaw the conclusion.
- if you do not know, say "I do not know"
customer input: {customer_input}
extracted preferencies: {extracted_preferences}
'''
summ_prompt = PromptTemplate.from_template(summarize_preferences_prompt_template)

# %%
summarizing_prompt = summ_prompt.format(customer_input=query, extracted_preferences = extracted_prefs)

# %%
summarized_preferences = instruct_llm(summarizing_prompt)
print(summarized_preferences)
# Out:
# The customer is looking for a 3 bedroom, 2 bathroom house with a view of the sea, with a budget of $2,000,000.

# %% [markdown]
# - Use to augment descriptions and personalize to the expectations

# %%
augmentation_prompt_template = '''
You are a real estate agent with great style to emphasize the property features to the customer preferences.
Based on the description of what the customer is looking for, the property description and property characteristics, rewrite a personalized, catchy, brief on the property enhancing those features.
- Be concise.
- Stick to what is provided to you. Do not alter or modify the customer preferences.
- only emphasize confirmed characteristics
- Do not invent preferences not mentionned by the customer since this could negatively flaw the conclusion.
- if you do not know, say "I do not know"
property descriptiont: {property_description}
customer preferences: {summarized_preferences}
'''
aug_prompt = PromptTemplate.from_template(augmentation_prompt_template)

# %%
def augment_properties(properties,summarized_preferences, df):
    '''   
    Takes in best property matches, summary of buyer preferences and initial property description
    Generates an augmented description for each selected property enhancing the buyer's features
    Display the augmented descriptions together with the exact characteristics of the properties
    inputs:
    - best property matches from find_best_matches function
    - summarized buyer preferences (str)
    - dataframe with detailed characteristics of the bast matches
    outputs:
    - dataframe with detailed characteristics of the bast matches and personalized, augmented, description using an LLM
    '''
    idx = df.index.to_list()
    
    keys = ['listings_neighborhood',
        'listings_price',
        'listings_bedrooms',
        'listings_bathrooms',
        'listings_house_size',
        #'listings_augmented_description',
        ]
    
    if len(idx) > 0:
        for id in idx:
            full_description = df.loc[id, 'full_description']
            augmentation_prompt = aug_prompt.format(property_description=full_description, summarized_preferences = summarized_preferences)
            augmented_desc = instruct_llm(augmentation_prompt)
            df.loc[id, 'augmented_description'] = augmented_desc
        
        for i, id in enumerate(idx):
            print(YELLOW + f"Distance {str(round(properties['distances'][0][i],3))} : {df.loc[id,'listings_headline']}" + ENDC)
            for key in keys:
                print(f'- {key.split("listings_")[1].replace("_"," "):<25} : {df.loc[id,key]}')
            
            display(Markdown('<span style="color:cyan">'+f'augmented description : {df.loc[id,"augmented_description"]}'+'</span>'))
            print('-------------------------------------------------')

    else:
        print(RED + "No match found with these characteristics" + ENDC)

    return df

# %% [markdown]
# ### RUBRIC #5 Use of LLM for Generating Personalized Descriptions

# %%
augmented_df = augment_properties(extrated_properties, summarized_preferences, matches_df)
# Out:
# Distance 0.439 : Seaside Retreat in Ocean View
# - neighborhood              : Ocean View
# - price                     : 1800000
# - bedrooms                  : 3
# - bathrooms                 : 2
# - house size                : 200
# <span style="color:cyan">augmented description :
# Welcome to your dream seaside retreat in Ocean View! This charming home boasts 3 bedrooms and 2 bathrooms, perfect for your family's needs. Step out onto the spacious deck and take in the breathtaking view of the ocean. Imagine waking up to the sound of waves crashing and enjoying your morning coffee with a stunning view. With a budget of $2,000,000, this home offers the perfect blend of coastal living and modern comfort. Located in the picturesque neighborhood of Ocean View, you'll have access to sandy beaches, delicious seafood restaurants, and a laid-back atmosphere. Don't miss out on the opportunity to experience the tranquility of seaside living in this charming community. </span>
# -------------------------------------------------
# Distance 0.51 : Modern Elegance in Silver Lake
# - neighborhood              : Silver Lake
# - price                     : 1900000
# - bedrooms                  : 3
# - bathrooms                 : 2
# - house size                : 210
# <span style="color:cyan">augmented description :
# "Experience modern elegance in this stunning 3-bedroom, 2-bathroom home located in the trendy Silver Lake neighborhood. With sleek design and high ceilings, this property exudes sophistication. But the real showstopper? The rooftop deck with panoramic views of the lake, perfect for enjoying the vibrant energy and creative spirit of this eclectic community. And with a budget of $2,000,000, this is the perfect opportunity to own a piece of Silver Lake's hip cafes, art galleries, and scenic lake views. Don't miss out on this modern gem!"</span>
# -------------------------------------------------

# %%
augmented_df
# Out:
#                  listings_headline listings_neighborhood  listings_price  \
# 1    Seaside Retreat in Ocean View            Ocean View         1800000
# 11  Modern Elegance in Silver Lake           Silver Lake         1900000
#
#     listings_bedrooms  listings_bathrooms  listings_house_size  \
# 1                   3                   2                  200
# 11                  3                   2                  210
#
#                                  listings_description  \
# 1   Escape to this charming seaside retreat in Oce...
# 11  Experience modern elegance in this 3-bedroom, ...
#
#                     listings_neighborhood_description  \
# 1   Ocean View is a picturesque coastal community ...
# 11  Silver Lake is a trendy neighborhood known for...
#
#                                      full_description  \
# 1   Seaside Retreat in Ocean View: Escape to this ...
# 11  Modern Elegance in Silver Lake: Experience mod...
#
#                                 augmented_description
# 1   \nWelcome to your dream seaside retreat in Oce...
# 11  \n"Experience modern elegance in this stunning...

# %% [markdown]
# # EXTRA: WORKFLOW WITH TOOL + FUNCTION CALLING TO EXTRACT AND REPOND WITH PERSONALIZED DESCRIPTIONS

# %% [markdown]
# - define tool to search for best match in property DB using pydantic structure

# %%
class GetBestPropertyMatchToolInput(BaseModel):
    """Call this function to find the properties best matching customer preferences"""
    query: str = Field(description="summary of the property's characteristics the customer looks for")
    metadata: Optional[dict] = Field(description="dictionary of metadata and value pairs of the target properties such as price, number of bedrooms, number of bathrooms, house surface, neighborhood")
    search_string: Optional[str] = Field(description="keyword to search for in the property description")
    n_results: Optional[NonNegativeInt] = Field(description="the number of property match to return - default = 3")


class GetBestPropertyMatchTool(BaseTool):
    name = "query_db"
    description = "Call this function to find the properties best matching customer preferences"

    def _run(self, query:str, metadata: Optional[dict] = None, search_string: Optional[str] = None, n_results: Optional[NonNegativeInt] = 3):
        """
        Run the tool and return the best match
        """
        # Query the database
        best_matches = query_db(query, metadata, search_string, n_results)  #TODO build_where_expression(metadata) ??
        return best_matches
    
    def _arun(self, query:str, metadata: Optional[dict] = None, search_string: Optional[str] = None, n_results: Optional[NonNegativeInt] = 3):
        """
        Run the tool and return the best match
        """
        raise NotImplementedError('This tool does not support async')
    
    args_schema: Type[BaseModel] = GetBestPropertyMatchToolInput


# Declare tools and functions
tools = [GetBestPropertyMatchTool()]
functions = [format_tool_to_openai_function(tool_name) for tool_name in tools]

# Set up a parser + inject instructions into the prompt template.
parser = PydanticOutputParser(pydantic_object=GetBestPropertyMatchToolInput)

# %%
tools[0]
# Out:
# GetBestPropertyMatchTool(name='query_db', description='Call this function to find the properties best matching customer preferences', args_schema=<class '__main__.GetBestPropertyMatchToolInput'>, return_direct=False, verbose=False, callbacks=None, callback_manager=None, tags=None, metadata=None, handle_tool_error=False)

# %%
functions
# Out:
# [{'name': 'query_db',
#   'description': 'Call this function to find the properties best matching customer preferences',
#   'parameters': {'description': 'Call this function to find the properties best matching customer preferences',
#    'properties': {'query': {'description': "summary of the property's characteristics the customer looks for",
#      'title': 'Query',
#      'type': 'string'},
#     'metadata': {'anyOf': [{'type': 'object'}, {'type': 'null'}],
#      'description': 'dictionary of metadata and value pairs of the target properties such as price, number of bedrooms, number of bathrooms, house surface, neighborhood',
#      'title': 'Metadata'},
#     'search_string': {'anyOf': [{'type': 'string'}, {'type': 'null'}],
#      'description': 'keyword to search for in the property description',
#      'title': 'Search String'},
#     'n_results': {'anyOf': [{'minimum': 0, 'type': 'integer'},
#       {'type': 'null'}],
#      'description': 'the number of property match to return - default = 3',
#      'title': 'N Results'}},
#    'required': ['query', 'metadata', 'search_string', 'n_results'],
#    'title': 'GetBestPropertyMatchToolInput',
#    'type': 'object'}}]

# %% [markdown]
# - generate function calling based on customer preferences

# %%
customer_input = "i am looking for a house with 3 bedrooms and a view on the lake?"
ai_response = chat_llm.predict_messages([HumanMessage(content=customer_input)], functions=functions)
# similar to response = chat_llm.invoke("i am looking for a house with 3 bedrooms and a view on the lake?", functions=functions)
ai_response
# Out:
# AIMessage(content='', additional_kwargs={'function_call': {'name': 'query_db', 'arguments': '{"query":"3 bedrooms, lake view","metadata":null,"search_string":null,"n_results":3}'}})

# %% [markdown]
# - extract function calling output

# %%
if ai_response.content=='':
    tool_name = ai_response.additional_kwargs['function_call']['name']
    tool = [tools[i] for i, tool in enumerate(tools) if tool.name==tool_name][0]
    _args = json.loads(ai_response.additional_kwargs['function_call']['arguments'])
print(tool.name)
print(_args)
extrated_properties = tool(_args)
extrated_properties
# Out:
# query_db
# {'query': '3 bedrooms, lake view', 'metadata': None, 'search_string': None, 'n_results': 3}
# {'ids': [['11', '1', '6']],
#  'distances': [[0.3404558433476212, 0.3557057768479667, 0.3824061701253278]],
#  'metadatas': [[{'bathrooms': 2,
#     'bedrooms': 3,
#     'house size': 210,
#     'neighborhood': 'Silver Lake',
#     'price': 1900000},
#    {'bathrooms': 2,
#     'bedrooms': 3,
#     'house size': 200,
#     'neighborhood': 'Ocean View',
#     'price': 1800000},
#    {'bathrooms': 3,
#     'bedrooms': 4,
#     'house size': 220,
#     'neighborhood': 'Maple Grove',
#     'price': 1300000}]],
#  'embeddings': None,
#  'documents': [['Modern Elegance in Silver Lake: Experience modern elegance in this 3-bedroom, 2-bathroom home in Silver Lake. With sleek design, high ceilings, and a rooftop deck with panoramic views of the lake, this property offers a perfect blend of style and sophistication. Neighborhood: Silver Lake is a trendy neighborhood known for its hip cafes, art galleries, and scenic lake views. Embrace the vibrant energy and creative spirit of this eclectic community.',
#    'Seaside Retreat in Ocean View: Escape to this charming seaside retreat in Ocean View. With 3 bedrooms, 2 bathrooms, and a spacious deck overlooking the ocean, this home offers a perfect blend of coastal living and modern comfort. Neighborhood: Ocean View is a picturesque coastal community with sandy beaches, seafood restaurants, and a laid-back atmosphere. Experience the tranquility of seaside living in this charming neighborhood.',
#    'Rustic Charm in Maple Grove: Discover the rustic charm of this 4-bedroom, 3-bathroom home in Maple Grove. With exposed wooden beams, a cozy fireplace, and a spacious backyard with a fire pit, this property offers a warm and inviting atmosphere. Neighborhood: Maple Grove is a quaint neighborhood with tree-lined streets, local cafes, and boutique shops. Enjoy a sense of community and small-town charm in this cozy enclave.']]}

# %% [markdown]
# - narrow down the list using threshold parameter

# %%
matches_df = display_matches(extrated_properties,0.37)
matches_df
# Out:
# Distance 0.34 : Modern Elegance in Silver Lake
# - neighborhood              : Silver Lake
# - price                     : 1900000
# - bedrooms                  : 3
# - bathrooms                 : 2
# - house size                : 210
# - description               : Experience modern elegance in this 3-bedroom, 2-bathroom home in Silver Lake. With sleek design, high ceilings, and a rooftop deck with panoramic views of the lake, this property offers a perfect blend of style and sophistication.
# - neighborhood description  : Silver Lake is a trendy neighborhood known for its hip cafes, art galleries, and scenic lake views. Embrace the vibrant energy and creative spirit of this eclectic community.
# -------------------------------------------------
# Distance 0.356 : Seaside Retreat in Ocean View
# - neighborhood              : Ocean View
# - price                     : 1800000
# - bedrooms                  : 3
# - bathrooms                 : 2
# - house size                : 200
# - description               : Escape to this charming seaside retreat in Ocean View. With 3 bedrooms, 2 bathrooms, and a spacious deck overlooking the ocean, this home offers a perfect blend of coastal living and modern comfort.
# - neighborhood description  : Ocean View is a picturesque coastal community with sandy beaches, seafood restaurants, and a laid-back atmosphere. Experience the tranquility of seaside living in this charming neighborhood.
# -------------------------------------------------
#                  listings_headline listings_neighborhood  listings_price  \
# 11  Modern Elegance in Silver Lake           Silver Lake         1900000
# 1    Seaside Retreat in Ocean View            Ocean View         1800000
#
#     listings_bedrooms  listings_bathrooms  listings_house_size  \
# 11                  3                   2                  210
# 1                   3                   2                  200
#
#                                  listings_description  \
# 11  Experience modern elegance in this 3-bedroom, ...
# 1   Escape to this charming seaside retreat in Oce...
#
#                     listings_neighborhood_description  \
# 11  Silver Lake is a trendy neighborhood known for...
# 1   Ocean View is a picturesque coastal community ...
#
#                                      full_description
# 11  Modern Elegance in Silver Lake: Experience mod...
# 1   Seaside Retreat in Ocean View: Escape to this ...

# %% [markdown]
# - generate augmented personalized descriptions

# %%
augmented_df = augment_properties(extrated_properties, customer_input, matches_df)
# Out:
# Distance 0.34 : Modern Elegance in Silver Lake
# - neighborhood              : Silver Lake
# - price                     : 1900000
# - bedrooms                  : 3
# - bathrooms                 : 2
# - house size                : 210
# <span style="color:cyan">augmented description :
# "Welcome to your dream home in Silver Lake! This stunning 3-bedroom, 2-bathroom property boasts modern elegance with its sleek design, high ceilings, and a rooftop deck offering breathtaking views of the lake. Immerse yourself in the trendy and vibrant neighborhood, known for its hip cafes, art galleries, and scenic lake views. Don't miss the opportunity to experience the perfect blend of style and sophistication in this sought-after community. Come see it for yourself!"</span>
# -------------------------------------------------
# Distance 0.356 : Seaside Retreat in Ocean View
# - neighborhood              : Ocean View
# - price                     : 1800000
# - bedrooms                  : 3
# - bathrooms                 : 2
# - house size                : 200
# <span style="color:cyan">augmented description :
# Welcome to your dream seaside retreat in Ocean View! This charming home boasts 3 bedrooms and a stunning view of the ocean from its spacious deck. Immerse yourself in the perfect blend of coastal living and modern comfort. Located in the picturesque neighborhood of Ocean View, you'll have access to sandy beaches, delicious seafood restaurants, and a laid-back atmosphere. Don't miss out on the opportunity to experience the tranquility of seaside living in this charming community. Come see it for yourself today!</span>
# -------------------------------------------------

# %% [markdown]
# - Generate final LLM response in natural language

# %%
final_output = chat_llm.predict_messages([ 
    HumanMessage(content=customer_input),
    ai_response,
    FunctionMessage(name=tool.name, content=str(extrated_properties)),
    AIMessage(content=str((augmented_df
                           .drop(['listings_description','listings_neighborhood_description','full_description'], axis=1)  # we keep the augmented description and the metadata characteristics
                           .to_dict(orient='dict')
                           )
                           ))
    ], 
    functions=functions
)
display(Markdown(final_output.content))
# Out:
# I found some properties that match your preferences:
#
# 1. **Modern Elegance in Silver Lake**
#    - **Neighborhood:** Silver Lake
#    - **Price:** $1,900,000
#    - **Bedrooms:** 3
#    - **Bathrooms:** 2
#    - **House Size:** 210 sqft
#    - **Description:** Welcome to your dream home in Silver Lake! This stunning 3-bedroom, 2-bathroom property boasts modern elegance with its sleek design, high ceilings, and a rooftop deck offering breathtaking views of the lake. Immerse yourself in the trendy and vibrant neighborhood, known for its hip cafes, art galleries, and scenic lake views. Don't miss the opportunity to experience the perfect blend of style and sophistication in this sought-after community. Come see it for yourself!
#
# 2. **Seaside Retreat in Ocean View**
#    - **Neighborhood:** Ocean View
#    - **Price:** $1,800,000
#    - **Bedrooms:** 3
#    - **Bathrooms:** 2
#    - **House Size:** 200 sqft
#    - **Description:** Welcome to your dream seaside retreat in Ocean View! This charming home boasts 3 bedrooms and a stunning view of the ocean from its spacious deck. Immerse yourself in the perfect blend of coastal living and modern comfort. Located in the picturesque neighborhood of Ocean View, you'll have access to sandy beaches, delicious seafood restaurants, and a laid-back atmosphere. Don't miss out on the opportunity to experience the tranquility of seaside living in this charming community. Come see it for yourself today!

# %% [markdown]
# # FULL AUTOMATIZED WORKFLOW with automated preference collection using tagging

# %%
from langchain.chains import create_tagging_chain, create_tagging_chain_pydantic
from enum import Enum
from pydantic.v1 import BaseModel, Field  # required due to bug issue in later pydantic version

# %%
chat_llm = ChatOpenAI(model='gpt-3.5-turbo-1106', temperature=0.1, max_tokens=3500)

# %%
class PreferenceDetails(BaseModel):
    price: NonNegativeInt = Field(description="This is the maximum price the customer can afford to buy a property.",default=0)
    #planned_price: NonNegativeInt = Field(description="This is the price amount the customer would prefer to spend to buy a property.",default=0)
    #neighborhood: str = Field(description="This is the neighborhood where the customer wants to buy a property",default='')
    bedrooms: NonNegativeInt = Field(description="This is the number of desired bedrooms for the property",default=0)
    bathrooms: NonNegativeInt = Field(description="This is the number of desired bathrooms for the property",default=0)
    size: NonNegativeInt = Field(#enum=["spanish", "english", "french", "german", "italian"]
                                description="This is the minimum desired size of the property in square meters",default=0)

# %%
# test
tt = PreferenceDetails()
tt
# Out:
# PreferenceDetails(price=0, bedrooms=0, bathrooms=0, size=0)

# %%
chain = create_tagging_chain_pydantic(PreferenceDetails, chat_llm)

# %%
# test
customer_input = "i am looking for a property with a view on the sea with 3 bedrooms, 3 bathrooms and maximum price of 2000000 euros"
res = chain.run(customer_input)
res
# Out:
# PreferenceDetails(price=2000000, bedrooms=3, bathrooms=3, size=0)

# %%
# check which metadata field are still unknown and empty
def check_what_is_empty(user_preferences):
    ask_for = []
    # Check if fields are empty
    for field, value in user_preferences.dict().items():
        if value in [None, "", 0]:  # You can add other 'empty' conditions as per your requirements
            print(RED + f"Field '{field}' is empty." + ENDC)
            ask_for.append(f'{field}')
    return ask_for

## checking the response and adding it
def add_non_empty_details(current_details: PreferenceDetails, new_details: PreferenceDetails):
    non_empty_details = {k: v for k, v in new_details.dict().items() if v not in [None, 0, ""]}
    updated_details = current_details.copy(update=non_empty_details)
    return updated_details


def ask_for_info(ask_for = ['maximum price','number of bedrooms', 'neighborhood']):

    # prompt template 1
    first_prompt = ChatPromptTemplate.from_template(
        "You are an real estate agent. Below is are some things to ask the customer for in a conversation way to understand his preferences. you should only ask one question at a time even if you don't get all the info \
        don't ask as a list! Don't greet the user! Don't say Hi. Explain you need to get some info to identify the best property match.\n\n \
        ### ask_for list: {ask_for}"  #If the ask_for list is empty then thank them and ask how you can help them 
    )

    # info_gathering_chain
    info_gathering_chain = LLMChain(llm=chat_llm, prompt=first_prompt)
    ai_chat = info_gathering_chain.run(ask_for=ask_for)
    return ai_chat


def filter_response(text_input, user_preferences ):
    tagging_chain = create_tagging_chain_pydantic(PreferenceDetails, chat_llm)
    res = tagging_chain.run(text_input)
    # add filtered info to the
    user_preferences = add_non_empty_details(user_preferences,res)
    ask_for = check_what_is_empty(user_preferences)
    return user_preferences, ask_for

# %%
user_preferences = PreferenceDetails()
ask_for = check_what_is_empty(user_preferences)

# while loop until all info are collected
while ask_for:
    ai_response = ask_for_info(ask_for) + ' Answer adding what your answer is about, e.g. "4 bedrooms"'    # THIS IS CRITICAL FOR THE LLM TO IDENTIFY THE CATEGORY SINCE NO MEMORY -> NO LINK BETWEEN QUESTION AND ANSWER (answer must make the obvious link with the subject of the question)
    print(YELLOW + ai_response + ENDC)
    customer_input = input(ai_response)
    print(GREEN + customer_input + ENDC)
    user_preferences, ask_for = filter_response(customer_input, user_preferences)
else:
    print('Thank you ! Everything has been gathered, moving now to next screening phase')

# final question to collect the gist of the ideal property
print(YELLOW + 'Besides these criteria, describe the property you would love to buy ?' + ENDC)
customer_input = input('Besides these criteria, describe the property you would love to buy ?')
print(GREEN + customer_input + ENDC)
# Out:
# Field 'price' is empty.
# Field 'bedrooms' is empty.
# Field 'bathrooms' is empty.
# Field 'size' is empty.
# What is your budget for the property you are looking for? Answer adding what your answer is about, e.g. "4 bedrooms"
# Field 'bedrooms' is empty.
# Field 'bathrooms' is empty.
# Field 'size' is empty.
# How many bedrooms are you looking for in a property? Answer adding what your answer is about, e.g. "4 bedrooms"
# Field 'bathrooms' is empty.
# Field 'size' is empty.
# How many bathrooms are you looking for in your ideal property? Answer adding what your answer is about, e.g. "4 bedrooms"
# Field 'size' is empty.
# What size of property are you looking for? Answer adding what your answer is about, e.g. "4 bedrooms"
# Thank you ! Everything has been gathered, moving now to next screening phase
# Besides these criteria, describe the property you would love to buy ?

# %%
user_preferences
# Out:
# PreferenceDetails(price=2500000, bedrooms=4, bathrooms=3, size=180)

# %%
# TRIGGER FUNCTION CALLING PARAMETERS
ai_response = chat_llm.predict_messages([HumanMessage(content=customer_input + ' Characteristics: ' + str(user_preferences.dict()))], functions=functions)
# similar to response = chat_llm.invoke("i am looking for a house with 3 bedrooms and a view on the lake?", functions=functions)
ai_response
# Out:
# AIMessage(content='', additional_kwargs={'function_call': {'name': 'query_db', 'arguments': '{"query":"quiet neighborhood, proximity to city","n_results":3}'}})

# %%
if ai_response.content=='':
    # EXECUTE FUNCTION CALLING
    tool_name = ai_response.additional_kwargs['function_call']['name']
    tool = [tools[i] for i, tool in enumerate(tools) if tool.name==tool_name][0]
    _args = json.loads(ai_response.additional_kwargs['function_call']['arguments'])

    print(tool.name)
    print(_args)
    extrated_properties = tool(_args)
    print(extrated_properties)
    # narrow down the list using threshold parameter
    matches_df = display_matches(extrated_properties,0.37)
    display(matches_df)

    # generate augmented personalized descriptions
    augmented_df = augment_properties(extrated_properties, customer_input, matches_df)
    # Generate final LLM response in natural language
    final_output = chat_llm.predict_messages([ 
            HumanMessage(content=customer_input),
            ai_response,
            FunctionMessage(name=tool.name, content=str(extrated_properties)),
            AIMessage(content=str((augmented_df
                                .drop(['listings_description','listings_neighborhood_description','full_description'], axis=1,errors='ignore')  # we keep the augmented description and the metadata characteristics
                                .to_dict(orient='dict')
                                )
                                ))
                                ], 
                                functions=functions
                            )
    # Print final recommendation in natural language
    display(Markdown(final_output.content))
# Out:
# query_db
# {'query': 'quiet neighborhood, proximity to city', 'n_results': 3}
# {'ids': [['5', '14', '15']], 'distances': [[0.3490514690109264, 0.36467161012339894, 0.36591028592542746]], 'metadatas': [[{'bathrooms': 2, 'bedrooms': 3, 'house size': 180, 'neighborhood': 'Downtown District', 'price': 2000000}, {'bathrooms': 2, 'bedrooms': 3, 'house size': 170, 'neighborhood': 'Cedar Valley', 'price': 1600000}, {'bathrooms': 3, 'bedrooms': 4, 'house size': 260, 'neighborhood': 'City Center', 'price': 2500000}]], 'embeddings': None, 'documents': [['Urban Chic in Downtown District: Embrace urban chic living in this stylish 3-bedroom, 2-bathroom home in the heart of the Downtown District. With modern design, high-end appliances, and a rooftop patio for entertaining, this property is perfect for those who love city living. Neighborhood: The Downtown District is a bustling urban center with a vibrant nightlife, trendy restaurants, and cultural attractions. Experience the excitement of city life right outside your doorstep.', 'Tranquil Retreat in Cedar Valley: Find peace and tranquility in this 3-bedroom, 2-bathroom home in Cedar Valley. Surrounded by cedar trees, with a wrap-around porch and a meditation garden, this property offers a serene retreat in a natural setting. Neighborhood: Cedar Valley is a peaceful neighborhood with hiking trails, nature reserves, and a strong sense of community. Enjoy the beauty of the outdoors and a slower pace of life in this idyllic enclave.', 'Urban Oasis in City Center: Discover an urban oasis in the heart of the City Center. This 4-bedroom, 3-bathroom home features modern design, a rooftop terrace with city views, and a home office, offering a perfect blend of style and functionality. Neighborhood: City Center is a vibrant urban hub with shopping centers, restaurants, and cultural attractions. Experience the convenience and excitement of city living in this bustling neighborhood.']]}
# Distance 0.349 : Urban Chic in Downtown District
# - neighborhood              : Downtown District
# - price                     : 2000000
# - bedrooms                  : 3
# - bathrooms                 : 2
# - house size                : 180
# - description               : Embrace urban chic living in this stylish 3-bedroom, 2-bathroom home in the heart of the Downtown District. With modern design, high-end appliances, and a rooftop patio for entertaining, this property is perfect for those who love city living.
# - neighborhood description  : The Downtown District is a bustling urban center with a vibrant nightlife, trendy restaurants, and cultural attractions. Experience the excitement of city life right outside your doorstep.
# -------------------------------------------------
# Distance 0.365 : Tranquil Retreat in Cedar Valley
# - neighborhood              : Cedar Valley
# - price                     : 1600000
# - bedrooms                  : 3
# - bathrooms                 : 2
# - house size                : 170
# - description               : Find peace and tranquility in this 3-bedroom, 2-bathroom home in Cedar Valley. Surrounded by cedar trees, with a wrap-around porch and a meditation garden, this property offers a serene retreat in a natural setting.
# - neighborhood description  : Cedar Valley is a peaceful neighborhood with hiking trails, nature reserves, and a strong sense of community. Enjoy the beauty of the outdoors and a slower pace of life in this idyllic enclave.
# -------------------------------------------------
# Distance 0.366 : Urban Oasis in City Center
# - neighborhood              : City Center
# - price                     : 2500000
# - bedrooms                  : 4
# - bathrooms                 : 3
# - house size                : 260
# - description               : Discover an urban oasis in the heart of the City Center. This 4-bedroom, 3-bathroom home features modern design, a rooftop terrace with city views, and a home office, offering a perfect blend of style and functionality.
# - neighborhood description  : City Center is a vibrant urban hub with shopping centers, restaurants, and cultural attractions. Experience the convenience and excitement of city living in this bustling neighborhood.
# -------------------------------------------------
#                    listings_headline listings_neighborhood  listings_price  \
# 5    Urban Chic in Downtown District     Downtown District         2000000
# 14  Tranquil Retreat in Cedar Valley          Cedar Valley         1600000
# 15        Urban Oasis in City Center           City Center         2500000
#
#     listings_bedrooms  listings_bathrooms  listings_house_size  \
# 5                   3                   2                  180
# 14                  3                   2                  170
# 15                  4                   3                  260
#
#                                  listings_description  \
# 5   Embrace urban chic living in this stylish 3-be...
# 14  Find peace and tranquility in this 3-bedroom, ...
# 15  Discover an urban oasis in the heart of the Ci...
#
#                     listings_neighborhood_description  \
# 5   The Downtown District is a bustling urban cent...
# 14  Cedar Valley is a peaceful neighborhood with h...
# 15  City Center is a vibrant urban hub with shoppi...
#
#                                      full_description
# 5   Urban Chic in Downtown District: Embrace urban...
# 14  Tranquil Retreat in Cedar Valley: Find peace a...
# 15  Urban Oasis in City Center: Discover an urban ...
# Distance 0.349 : Urban Chic in Downtown District
# - neighborhood              : Downtown District
# - price                     : 2000000
# - bedrooms                  : 3
# - bathrooms                 : 2
# - house size                : 180
# <span style="color:cyan">augmented description :
# Looking for the perfect blend of city living and peaceful surroundings? Look no further than this stunning 3-bedroom, 2-bathroom home in the heart of the Downtown District. With its modern design, high-end appliances, and rooftop patio for entertaining, this property is the epitome of urban chic. And with its location in a quiet neighborhood just steps away from the bustling city center, you can have the best of both worlds. Don't miss out on the opportunity to experience the excitement of city life while still enjoying a tranquil living environment.</span>
# -------------------------------------------------
# Distance 0.365 : Tranquil Retreat in Cedar Valley
# - neighborhood              : Cedar Valley
# - price                     : 1600000
# - bedrooms                  : 3
# - bathrooms                 : 2
# - house size                : 170
# <span style="color:cyan">augmented description :
# Welcome to your tranquil retreat in Cedar Valley! This stunning 3-bedroom, 2-bathroom home is nestled among the beautiful cedar trees, providing a peaceful and serene atmosphere. Step onto the wrap-around porch and take in the natural surroundings, or find your inner peace in the meditation garden. Located in the quiet neighborhood of Cedar Valley, you'll have access to hiking trails, nature reserves, and a strong sense of community. Enjoy the best of both worlds with a peaceful escape from the city, while still being in close proximity. Don't miss out on this idyllic enclave - schedule a viewing today!</span>
# -------------------------------------------------
# Distance 0.366 : Urban Oasis in City Center
# - neighborhood              : City Center
# - price                     : 2500000
# - bedrooms                  : 4
# - bathrooms                 : 3
# - house size                : 260
# <span style="color:cyan">augmented description :
# Welcome to your dream home in the City Center! This stunning 4-bedroom, 3-bathroom oasis offers the perfect balance of tranquility and city living. With a modern design and a rooftop terrace boasting breathtaking city views, you'll never want to leave. Need to work from home? No problem, this home also features a convenient home office. And with its prime location in the bustling City Center, you'll have easy access to shopping, dining, and cultural attractions. Say goodbye to noisy neighborhoods and hello to your peaceful urban retreat.</span>
# -------------------------------------------------
# Based on your preferences, here are the top 3 property matches:
#
# 1. Urban Chic in Downtown District
#    - Neighborhood: Downtown District
#    - Price: $2,000,000
#    - Bedrooms: 3
#    - Bathrooms: 2
#    - House Size: 180 sq. ft
#    - Description: Looking for the perfect blend of city living and peaceful surroundings? Look no further than this stunning 3-bedroom, 2-bathroom home in the heart of the Downtown District. With its modern design, high-end appliances, and rooftop patio for entertaining, this property is the epitome of urban chic. And with its location in a quiet neighborhood just steps away from the bustling city center, you can have the best of both worlds. Don't miss out on the opportunity to experience the excitement of city life while still enjoying a tranquil living environment.
#
# 2. Tranquil Retreat in Cedar Valley
#    - Neighborhood: Cedar Valley
#    - Price: $1,600,000
#    - Bedrooms: 3
#    - Bathrooms: 2
#    - House Size: 170 sq. ft
#    - Description: Welcome to your tranquil retreat in Cedar Valley! This stunning 3-bedroom, 2-bathroom home is nestled among the beautiful cedar trees, providing a peaceful and serene atmosphere. Step onto the wrap-around porch and take in the natural surroundings, or find your inner peace in the meditation garden. Located in the quiet neighborhood of Cedar Valley, you'll have access to hiking trails, nature reserves, and a strong sense of community. Enjoy the best of both worlds with a peaceful escape from the city, while still being in close proximity. Don't miss out on this idyllic enclave - schedule a viewing today!
#
# 3. Urban Oasis in City Center
#    - Neighborhood: City Center
#    - Price: $2,500,000
#    - Bedrooms: 4
#    - Bathrooms: 3
#    - House Size: 260 sq. ft
#    - Description: Welcome to your dream home in the City Center! This stunning 4-bedroom, 3-bathroom oasis offers the perfect balance of tranquility and city living. With a modern design and a rooftop terrace boasting breathtaking city views, you'll never want to leave. Need to work from home? No problem, this home also features a convenient home office. And with its prime location in the bustling City Center, you'll have easy access to shopping, dining, and cultural attractions. Say goodbye to noisy neighborhoods and hello to your peaceful urban retreat.

# %% [markdown]
# # OUT

# %%
'''system_template="You are a real estate agent. You engage conversation with the customers to understand their needs and provide them with the best possible property. Your task is to collect the necessary selection criteria of the customer."
system_message_prompt = SystemMessagePromptTemplate.from_template(system_template)
ai_template_1 = "Hi! I am here to help you find the best property for you. Could you please tell me about the ideal characteristics of the property you are lookiging for?"
ai_message_1= AIMessagePromptTemplate.from_template(ai_template_1)
human_template="{customer_input}" 
human_message_prompt = HumanMessagePromptTemplate.from_template(human_template)
ai_template_2="{response}"
ai_message_2 = AIMessagePromptTemplate.from_template(ai_template_2)
chat_prompt = ChatPromptTemplate.from_messages([system_message_prompt,ai_message_1, human_message_prompt,ai_message_2])
llm_chain = LLMChain(prompt=chat_prompt, llm=chat_llm)
customer_input="i am looking for a house with 3 bedrooms and a view on the lake. What do you propose?"
response1 = llm_chain.run(response="", customer_input=customer_input, functions=functions)
display(Markdown(response1))'''
# Out:
# Great! A house with 3 bedrooms and a view of the lake sounds wonderful. Are there any other specific features or amenities you are looking for in the property? For example, do you prefer a modern or traditional style, a certain neighborhood, or any specific budget in mind?

# %%
"""

prompt = '''You are a helpful telcom sales assistant. In order to help someone to the right plan you need the city a person is based on wether the person is look for an individual plan or a family plan. 

For an individual plan- just ask the age of the person. 

If It is a family plan - we need to know how many people are on it and what there ages are for each person. 
The max for a family plan is set to 5. 
In order to provide a quote - you will need to have the ages of all people on the plan.

When people provide only the city name, please infer the State and then confirm with the person. Like when they say 'Atlanta' - you ask something like 'So you are in Atlanta, Georgia right?

Once you have all the information (Individual or family plan, number of people and age for EACH person, city and state) you can call the plan function that will return the price. '''
functions = [

{
  "name": "getplanprice",
  "parameters": {
    "type": "object",
    "properties": {
      "plan": {
        "type": "string",
        "Description": "Individual or Family"
      },
      "people": {
        "type": "integer",
        "description": "The number of people on the plan"
      },
      "ages": {
        "type": "string",
        "description": "Commma separates list of the ages of all plan participants"
      }
    },
    "required": [
      "plan",
      "people",
      "ages"
    ]
  },
  "description": "Needs the city/state, the type of plan, the number of peole on the plan and the ages of the people"
}


]

- we use a set of defined Q & A
personal_questions = [  "Which movie genre you like the most?", 
                        "What is your favorite color?", 
                        "What is your favorite movie?", 
                        "Pick one - dogs, cats or hamsters?",
                        "What is your favorite food?",
                        "What is your favorite drink?" ]

#personal_answers = [ ] 
#for question in personal_questions:
#    answer = input(question)
#    personal_answers.append(answer)
    
personal_answers = ['thriller', 'blue', 'inception', 'dogs', 'fish tacos', 'cold beer']"""
